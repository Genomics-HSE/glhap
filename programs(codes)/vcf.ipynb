# %%
from anytree import NodeMixin, RenderTree
import numpy as np
import pysam
import allel
from pysam import VariantFile, FastaFile

# %%
class Node(NodeMixin):
    def __init__(self, name, snps, parent=None, children=None):
#         super(MyClass, self).__init__()
        self.name = name
        self.snps = snps
        self.parent = parent
        self.lh = 0
        if children:  # set children only if given
             self.children = children
    
    def __repr__(self):
             return self.name +" "+ str(self.lh)
    def __str__(self):
        return self.name

# %%
def get_snp(node):
    issnp = False
    snp = list()
    atgc = set(['A','T','G','C','a','t','g','c'])
    for i in range(2,len(node)):
        if node[i][0] in atgc and node[i][-1] in atgc:
            snp.append([node[i][0],node[i][-1],int(node[i][1:-1])])
    return snp

# %%
def make_tree(tree,node,pos=0):     
    posit = pos + 1
    i = posit
    while i<len(tree) and tree[i][0] >= tree[pos][0]+1:
        if tree[i][0] == tree[pos][0]+1:
#             print(node.name,tree[i][1])
            snps = get_snp(tree[i])
            tmp = Node(tree[i][1],snps,parent=node)
            make_tree(tree,tmp,i)

        i += 1

# %%
import json

with open('PhyloTree.org-parser/array.json') as f:
    d = json.load(f) # d - это список python
#     print(d)
for i in d:
    i[0] += 1
d[0][0]=0

# print(d)

# %%
def get_log_monozygous(bcf: VariantFile):
    '''
    Логарифмы вероятностей нуклеотидов для vcf файла
    
    '''
    gls = np.full((16569,4),-1)
    for rec in bcf.fetch():
        pos = rec.pos
        pls = rec.samples.values()[0]['PL']
        alt = rec.alleles
        k = 0
        s = 2
        for i in range(len(alt)):
            if alt[i] == 'A':
                gls[pos-1][0] = pls[k]
            elif alt[i] == 'T':
                gls[pos-1][1] = pls[k]
            elif alt[i] == 'G':
                gls[pos-1][2] = pls[k]
            elif alt[i] == 'C':
                gls[pos-1][3] = pls[k]
            elif alt[i] == '<*>':
                for j in range(4):
                    if gls[pos-1][j] == -1:
                        gls[pos-1][j] = pls[k]
            k += s
            s += 1
    return -gls/10

# %%
a = Node(d[0][1],[])
make_tree(d,a,0)

# %%
a.children[0].snps
# Out:
# [['G', 'A', 263],
#  ['C', 'T', 1048],
#  ['C', 'a', 3516],
#  ['T', 'C', 5442],
#  ['T', 'C', 6185],
#  ['C', 'T', 9042],
#  ['A', 'G', 9347],
#  ['G', 'A', 10589],
#  ['G', 'A', 12007],
#  ['A', 'G', 12720]]

# %%
ref.fetch('chrM')[25]
# Out:
# 'C'

# %%
print(RenderTree(a))
# Out:
# mt-MRCA (RSRS) -2206.2
# ├── L0 -2376.1
# │   ├── L0a'b'f'g'k -2419.7
# │   │   ├── L0a'b'f'g -2583.4999999999995
# │   │   │   ├── L0a'b'g -2653.3999999999996
# │   │   │   │   ├── L0a'g -2678.8999999999996
# │   │   │   │   │   ├── L0a -2704.3999999999996
# │   │   │   │   │   │   ├── L0a1'4 -2729.8999999999996
# │   │   │   │   │   │   │   ├── L0a1 -2729.8999999999996
# │   │   │   │   │   │   │   │   ├── L0a1a -2729.8999999999996
# │   │   │   │   │   │   │   │   │   └── - -2748.7
# │   │   │   │   │   │   │   │   │       ├── L0a1a1 -2774.2
# │   │   │   │   │   │   │   │   │       ├── L0a1a2 -2792.3999999999996
# │   │   │   │   │   │   │   │   │       └── L0a1a3 -2774.2
# │   │   │   │   │   │   │   │   ├── - -2755.3999999999996
# │   │   │   │   │   │   │   │   │   ├── L0a1b -2806.3999999999996
# │   │   │   │   │   │   │   │   │   │   ├── L0a1b1 -2850.0999999999995
# │   │   │   │   │   │   │   │   │   │   │   └── L0a1b1a -2875.5999999999995
# │   │   │   │   │   │   │   │   │   │   │       └── L0a1b1a1 -2875.5999999999995
# │   │   │   │   │   │   │   │   │   │   │           └── L0a1b1a1a -2926.5999999999995
# │   │   │   │   │   │   │   │   │   │   └── L0a1b2 -2857.3999999999996
# │   │   │   │   │   │   │   │   │   │       └── L0a1b2a -2882.8999999999996
# │   │   │   │   │   │   │   │   │   ├── L0a1c -2780.8999999999996
# │   │   │   │   │   │   │   │   │   │   └── L0a1c1 -2857.3999999999996
# │   │   │   │   │   │   │   │   │   └── L0a1d -2755.3999999999996
# │   │   │   │   │   │   │   │   └── L0a1e -2799.0999999999995
# │   │   │   │   │   │   │   └── L0a4 -3028.5999999999995
# │   │   │   │   │   │   ├── L0a2 -2873.4999999999995
# │   │   │   │   │   │   │   ├── L0a2a -2898.9999999999995
# │   │   │   │   │   │   │   │   ├── L0a2a1 -2924.4999999999995
# │   │   │   │   │   │   │   │   │   ├── L0a2a1a -2924.4999999999995
# │   │   │   │   │   │   │   │   │   │   ├── L0a2a1a1 -2975.4999999999995
# │   │   │   │   │   │   │   │   │   │   └── L0a2a1a2 -2975.4999999999995
# │   │   │   │   │   │   │   │   │   └── L0a2a1b -2975.4999999999995
# │   │   │   │   │   │   │   │   └── L0a2a2 -2962.1
# │   │   │   │   │   │   │   │       └── L0a2a2a -2987.6
# │   │   │   │   │   │   │   │           ├── L0a2a2a1 -3038.6
# │   │   │   │   │   │   │   │           └── L0a2a2a2 -3013.1
# │   │   │   │   │   │   │   ├── L0a2b -3019.1999999999994
# │   │   │   │   │   │   │   │   └── L0a2b1 -3044.6999999999994
# │   │   │   │   │   │   │   ├── L0a2c -3070.1999999999994
# │   │   │   │   │   │   │   └── L0a2d -2924.4999999999995
# │   │   │   │   │   │   └── L0a3 -2729.8999999999996
# │   │   │   │   │   └── L0g -3168.2
# │   │   │   │   └── L0b -2806.3999999999996
# │   │   │   └── L0f -2787.4999999999995
# │   │   │       ├── L0f1 -2882.1999999999994
# │   │   │       └── L0f2 -2838.4999999999995
# │   │   │           ├── L0f2a -2914.9999999999995
# │   │   │           │   └── L0f2a1 -3136.9999999999995
# │   │   │           └── L0f2b -3299.099999999999
# │   │   └── L0k -3057.2
# │   │       ├── L0k1 -3108.2
# │   │       │   ├── L0k1a -3177.3999999999996
# │   │       │   │   ├── L0k1a1 -3196.2
# │   │       │   │   │   ├── L0k1a1a -3189.5
# │   │       │   │   │   ├── L0k1a1b -3221.7
# │   │       │   │   │   ├── L0k1a1c -3221.7
# │   │       │   │   │   └── L0k1a1d -3221.7
# │   │       │   │   ├── L0k1a2 -3202.8999999999996
# │   │       │   │   │   └── L0k1a2a -3202.8999999999996
# │   │       │   │   └── L0k1a3 -3253.8999999999996
# │   │       │   └── L0k1b -3205.6
# │   │       └── L0k2 -3152.5
# │   │           ├── L0k2a -3229.0
# │   │           │   └── L0k2a1 -3254.5
# │   │           │       └── L0k2a1a -3331.0
# │   │           └── L0k2b -3178.0
# │   └── L0d -2554.6
# │       ├── L0d1'2 -2580.1
# │       │   ├── L0d1 -2655.1
# │       │   │   ├── L0d1a'c'd -2680.6
# │       │   │   │   ├── L0d1a'd -2724.2999999999997
# │       │   │   │   │   ├── L0d1a -2826.2999999999997
# │       │   │   │   │   │   └── L0d1a1 -2851.7999999999997
# │       │   │   │   │   │       ├── L0d1a1a -2902.7999999999997
# │       │   │   │   │   │       │   ├── L0d1a1a1 -2902.7999999999997
# │       │   │   │   │   │       │   ├── L0d1a1a2 -2902.7999999999997
# │       │   │   │   │   │       │   └── L0d1a1a3 -2928.2999999999997
# │       │   │   │   │   │       ├── L0d1a1b -2902.7999999999997
# │       │   │   │   │   │       │   └── L0d1a1b1 -2946.4999999999995
# │       │   │   │   │   │       │       ├── L0d1a1b1a -2946.4999999999995
# │       │   │   │   │   │       │       └── L0d1a1b1b -2971.9999999999995
# │       │   │   │   │   │       ├── L0d1a1c -2920.9999999999995
# │       │   │   │   │   │       └── L0d1a1d -2877.2999999999997
# │       │   │   │   │   └── L0d1d -2928.2999999999997
# │       │   │   │   └── L0d1c -2802.5
# │       │   │   │       ├── L0d1c1 -2853.5
# │       │   │   │       │   └── L0d1c1a -2904.5
# │       │   │   │       │       ├── L0d1c1a1 -2948.2
# │       │   │   │       │       │   ├── L0d1c1a1a -2973.7
# │       │   │   │       │       │   │   ├── L0d1c1a1a1 -2973.7
# │       │   │   │       │       │   │   └── L0d1c1a1a2 -2999.2
# │       │   │   │       │       │   └── L0d1c1a1b -2973.7
# │       │   │   │       │       └── L0d1c1a2 -2922.7
# │       │   │   │       ├── L0d1c2 -2828.0
# │       │   │   │       │   └── L0d1c2a -2897.8
# │       │   │   │       │       └── L0d1c2a1 -2974.3
# │       │   │   │       └── L0d1c3 -2853.5
# │       │   │   └── L0d1b -2680.6
# │       │   │       ├── L0d1b1 -2724.2
# │       │   │       │   ├── L0d1b1a -2851.7
# │       │   │       │   │   └── L0d1b1a1 -2877.2
# │       │   │       │   ├── L0d1b1b -2724.2
# │       │   │       │   │   └── L0d1b1b1 -2812.8
# │       │   │       │   └── - -2742.3999999999996
# │       │   │       │       └── L0d1b1c -2795.8999999999996
# │       │   │       └── L0d1b2 -2757.1
# │       │   │           ├── L0d1b2a -2859.1
# │       │   │           │   ├── L0d1b2a1 -2884.6
# │       │   │           │   └── L0d1b2a2 -2935.6
# │       │   │           └── L0d1b2b -2782.6
# │       │   │               ├── L0d1b2b1 -2833.6
# │       │   │               │   ├── L0d1b2b1a -2986.6
# │       │   │               │   └── L0d1b2b1b -2884.6
# │       │   │               │       └── L0d1b2b1b1 -2910.1
# │       │   │               └── L0d1b2b2 -2833.6
# │       │   │                   ├── L0d1b2b2a -2859.1
# │       │   │                   ├── L0d1b2b2b -2859.1
# │       │   │                   │   └── L0d1b2b2b1 -2910.1
# │       │   │                   └── L0d1b2b2c -2833.6
# │       │   │                       ├── L0d1b2b2c1 -2859.1
# │       │   │                       └── L0d1b2b2c2 -2884.6
# │       │   └── L0d2 -2656.6
# │       │       ├── L0d2a'b'd -2682.1
# │       │       │   ├── L0d2a -2758.6
# │       │       │   │   ├── L0d2a1 -2853.2999999999997
# │       │       │   │   │   ├── L0d2a1a -2878.7999999999997
# │       │       │   │   │   │   ├── L0d2a1a1 -2878.7999999999997
# │       │       │   │   │   │   │   └── L0d2a1a1a -2904.2999999999997
# │       │       │   │   │   │   ├── L0d2a1a2 -2904.2999999999997
# │       │       │   │   │   │   └── L0d2a1a3 -2878.7999999999997
# │       │       │   │   │   ├── L0d2a1b -2904.2999999999997
# │       │       │   │   │   └── L0d2a1c -2929.7999999999997
# │       │       │   │   └── L0d2a2 -2929.7
# │       │       │   ├── L0d2b -2802.2999999999997
# │       │       │   │   ├── L0d2b1 -3006.2999999999997
# │       │       │   │   │   ├── L0d2b1a -3030.7
# │       │       │   │   │   │   └── L0d2b1a1 -3081.7
# │       │       │   │   │   │       └── L0d2b1a1a -3107.2
# │       │       │   │   │   └── L0d2b1b -3057.2999999999997
# │       │       │   │   └── L0d2b2 -2870.7
# │       │       │   └── L0d2d -2933.7
# │       │       └── L0d2c -2928.4
# │       │           ├── L0d2c1 -2953.9
# │       │           │   ├── L0d2c1a -2979.4
# │       │           │   │   └── L0d2c1a1 -3030.4
# │       │           │   └── L0d2c1b -3004.9
# │       │           └── L0d2c2 -3015.7
# │       │               ├── L0d2c2a -3041.2
# │       │               │   └── L0d2c2a1 -3066.7
# │       │               │       └── L0d2c2a1a -3092.2
# │       │               └── L0d2c2b -3066.7
# │       └── L0d3 -2894.5
# │           ├── L0d3a -2996.5
# │           └── L0d3b -3040.2
# │               ├── L0d3b1 -3040.2
# │               └── L0d3b2 -3065.7
# └── L1'2'3'4'5'6 -2300.7999999999997
#     ├── L1 -2428.2999999999997
#     │   ├── L1b -2826.2999999999997
#     │   │   ├── L1b1 -2953.7999999999997
#     │   │   │   └── L1b1a -2979.2999999999997
#     │   │   │       ├── L1b1a1'4 -3004.7999999999997
#     │   │   │       │   ├── L1b1a1 -3072.7
#     │   │   │       │   └── L1b1a4 -3030.2999999999997
#     │   │   │       │       └── L1b1a4a -3030.2999999999997
#     │   │   │       ├── L1b1a2 -3004.7999999999997
#     │   │   │       │   └── L1b1a2a -3030.2999999999997
#     │   │   │       ├── - -2997.3999999999996
#     │   │   │       │   ├── L1b1a3 -3022.8999999999996
#     │   │   │       │   │   ├── L1b1a3a -3048.3999999999996
#     │   │   │       │   │   │   └── L1b1a3a1 -3073.8999999999996
#     │   │   │       │   │   └── L1b1a3b -3073.8999999999996
#     │   │   │       │   ├── L1b1a9 -2997.3999999999996
#     │   │   │       │   ├── L1b1a15 -2997.3999999999996
#     │   │   │       │   │   └── L1b1a15a -3022.8999999999996
#     │   │   │       │   ├── L1b1a17 -3022.8999999999996
#     │   │   │       │   └── L1b1a18 -3048.3999999999996
#     │   │   │       ├── L1b1a5 -3004.7999999999997
#     │   │   │       ├── L1b1a6 -3004.7999999999997
#     │   │   │       ├── L1b1a7 -2979.2999999999997
#     │   │   │       │   └── L1b1a7a -3023.3999999999996
#     │   │   │       ├── L1b1a8 -3004.7999999999997
#     │   │   │       ├── L1b1a10 -2997.4999999999995
#     │   │   │       │   ├── L1b1a10a -2997.4999999999995
#     │   │   │       │   └── L1b1a10b -2997.4999999999995
#     │   │   │       ├── L1b1a12 -3030.2999999999997
#     │   │   │       │   ├── L1b1a12a -3055.7999999999997
#     │   │   │       │   └── L1b1a12b -3081.2999999999997
#     │   │   │       ├── L1b1a13 -3004.7999999999997
#     │   │   │       ├── L1b1a14 -3004.7999999999997
#     │   │   │       └── L1b1a16 -3004.7999999999997
#     │   │   └── L1b2'3 -2844.4999999999995
#     │   │       ├── L1b2 -2939.0999999999995
#     │   │       │   └── L1b2a -2964.5999999999995
#     │   │       └── L1b3 -2942.8999999999996
#     │   └── L1c -2713.3999999999996
#     │       ├── L1c1'2'4'5'6 -2730.2
#     │       │   ├── L1c1'2'4'6 -2748.3999999999996
#     │       │   │   ├── L1c1 -2850.3999999999996
#     │       │   │   │   ├── L1c1a'b'd -2875.8999999999996
#     │       │   │   │   │   ├── L1c1a -2926.8999999999996
#     │       │   │   │   │   │   └── - -2926.8999999999996
#     │       │   │   │   │   │       ├── L1c1a1 -2977.8999999999996
#     │       │   │   │   │   │       │   ├── L1c1a1a -3073.2
#     │       │   │   │   │   │       │   │   ├── L1c1a1a1 -3200.7
#     │       │   │   │   │   │       │   │   │   ├── L1c1a1a1a -3251.7
#     │       │   │   │   │   │       │   │   │   └── L1c1a1a1b -3251.7
#     │       │   │   │   │   │       │   │   │       └── L1c1a1a1b1 -3277.2
#     │       │   │   │   │   │       │   │   └── L1c1a1a2 -3124.2
#     │       │   │   │   │   │       │   └── L1c1a1b -3200.0999999999995
#     │       │   │   │   │   │       └── L1c1a2 -3142.3999999999996
#     │       │   │   │   │   │           ├── L1c1a2a -3167.8999999999996
#     │       │   │   │   │   │           │   ├── L1c1a2a1 -3167.8999999999996
#     │       │   │   │   │   │           │   └── L1c1a2a2 -3193.3999999999996
#     │       │   │   │   │   │           ├── L1c1a2b -3237.0999999999995
#     │       │   │   │   │   │           └── L1c1a2c -3218.8999999999996
#     │       │   │   │   │   └── L1c1b'd -2901.3999999999996
#     │       │   │   │   │       ├── L1c1b -3054.3999999999996
#     │       │   │   │   │       │   └── L1c1b1 -3156.3999999999996
#     │       │   │   │   │       └── L1c1d -2952.3999999999996
#     │       │   │   │   │           └── L1c1d1 -2952.3999999999996
#     │       │   │   │   └── L1c1c -3028.8999999999996
#     │       │   │   ├── L1c2'4 -2799.3999999999996
#     │       │   │   │   ├── L1c2 -3003.3999999999996
#     │       │   │   │   │   ├── L1c2a -3079.8999999999996
#     │       │   │   │   │   │   ├── L1c2a1 -3105.3999999999996
#     │       │   │   │   │   │   │   ├── L1c2a1a -3207.3999999999996
#     │       │   │   │   │   │   │   └── L1c2a1b -3105.3999999999996
#     │       │   │   │   │   │   ├── L1c2a2 -3257.2999999999997
#     │       │   │   │   │   │   └── L1c2a3 -3150.9999999999995
#     │       │   │   │   │   │       └── L1c2a3a -3227.4999999999995
#     │       │   │   │   │   └── L1c2b -3028.8999999999996
#     │       │   │   │   │       ├── L1c2b1 -3054.3999999999996
#     │       │   │   │   │       │   ├── L1c2b1a'b -3079.8999999999996
#     │       │   │   │   │       │   │   ├── L1c2b1a -3105.3999999999996
#     │       │   │   │   │       │   │   │   └── L1c2b1a1 -3156.3999999999996
#     │       │   │   │   │       │   │   └── L1c2b1b -3156.3999999999996
#     │       │   │   │   │       │   │       └── L1c2b1b1 -3224.2999999999997
#     │       │   │   │   │       │   └── L1c2b1c -3202.2
#     │       │   │   │   │       └── L1c2b2 -3079.8999999999996
#     │       │   │   │   └── L1c4 -3002.3999999999996
#     │       │   │   │       ├── L1c4a -3301.9999999999995
#     │       │   │   │       └── L1c4b -3053.3999999999996
#     │       │   │   └── L1c6 -2773.8999999999996
#     │       │   └── L1c5 -3051.9
#     │       └── L1c3 -2859.0999999999995
#     │           ├── L1c3a -3037.5999999999995
#     │           │   └── L1c3a1 -3063.0999999999995
#     │           │       ├── L1c3a1a -3088.5999999999995
#     │           │       └── L1c3a1b -3114.0999999999995
#     │           └── L1c3b'c -2910.0999999999995
#     │               ├── L1c3b -2935.5999999999995
#     │               │   ├── L1c3b1 -3075.9999999999995
#     │               │   │   ├── L1c3b1a -3152.4999999999995
#     │               │   │   └── L1c3b1b -3126.9999999999995
#     │               │   └── L1c3b2 -3139.5999999999995
#     │               └── L1c3c -3152.8999999999996
#     └── L2'3'4'5'6 -2369.9999999999995
#         ├── L5 -2471.9999999999995
#         │   ├── L5a -3082.8999999999996
#         │   │   ├── L5a1 -3082.8999999999996
#         │   │   │   ├── L5a1a -3108.3999999999996
#         │   │   │   ├── L5a1b -3108.3999999999996
#         │   │   │   └── L5a1c -3128.7
#         │   │   └── L5a2 -3108.3999999999996
#         │   └── L5b -2548.4999999999995
#         │       ├── L5b1 -2948.5999999999995
#         │       │   ├── L5b1a -3025.0999999999995
#         │       │   └── L5b1b -2974.0999999999995
#         │       └── L5b2 -3153.1999999999994
#         └── L2'3'4'6 -2611.0999999999995
#             ├── L2 -2782.2999999999993
#             │   ├── L2a'b'c'd -2782.2999999999993
#             │   │   ├── L2a -2807.7999999999993
#             │   │   │   ├── L2a1'2'3'4 -2884.2999999999993
#             │   │   │   │   ├── L2a1 -2960.7999999999993
#             │   │   │   │   │   ├── L2a1a -3062.7999999999993
#             │   │   │   │   │   │   ├── L2a1a1 -3139.2999999999993
#             │   │   │   │   │   │   ├── L2a1a2 -3088.2999999999993
#             │   │   │   │   │   │   │   ├── L2a1a2a -3113.7999999999993
#             │   │   │   │   │   │   │   │   └── L2a1a2a1 -3113.7999999999993
#             │   │   │   │   │   │   │   │       └── L2a1a2a1a -3139.2999999999993
#             │   │   │   │   │   │   │   ├── L2a1a2b -3113.7999999999993
#             │   │   │   │   │   │   │   └── L2a1a2c -3088.2999999999993
#             │   │   │   │   │   │   └── L2a1a3 -3080.7999999999993
#             │   │   │   │   │   │       ├── L2a1a3a -3080.7999999999993
#             │   │   │   │   │   │       ├── L2a1a3b -3080.7999999999993
#             │   │   │   │   │   │       └── L2a1a3c -3106.2999999999993
#             │   │   │   │   │   ├── - -2960.7999999999993
#             │   │   │   │   │   │   ├── L2a1b -2960.7999999999993
#             │   │   │   │   │   │   │   ├── L2a1b1 -2986.2999999999993
#             │   │   │   │   │   │   │   │   └── L2a1b1a -3011.7999999999993
#             │   │   │   │   │   │   │   ├── L2a1b2 -2960.7999999999993
#             │   │   │   │   │   │   │   └── - -2978.7999999999993
#             │   │   │   │   │   │   │       └── L2a1b3 -3023.0999999999995
#             │   │   │   │   │   │   ├── L2a1f -2986.2999999999993
#             │   │   │   │   │   │   │   ├── L2a1f1 -2963.2999999999993
#             │   │   │   │   │   │   │   │   └── L2a1f1a -2988.7999999999993
#             │   │   │   │   │   │   │   ├── L2a1f2 -3011.7999999999993
#             │   │   │   │   │   │   │   └── L2a1f3 -3004.499999999999
#             │   │   │   │   │   │   └── L2a1g -3088.2999999999993
#             │   │   │   │   │   └── - -2978.7999999999993
#             │   │   │   │   │       ├── L2a1c -3004.2999999999993
#             │   │   │   │   │       │   ├── - -3029.7999999999993
#             │   │   │   │   │       │   │   ├── L2a1c1 -3073.499999999999
#             │   │   │   │   │       │   │   │   └── L2a1c1a -3098.999999999999
#             │   │   │   │   │       │   │   │       ├── L2a1c1a1 -3124.499999999999
#             │   │   │   │   │       │   │   │       └── L2a1c1a2 -3098.999999999999
#             │   │   │   │   │       │   │   └── L2a1c6 -3098.899999999999
#             │   │   │   │   │       │   ├── L2a1c2 -3055.2999999999993
#             │   │   │   │   │       │   │   └── L2a1c2a -3126.5999999999995
#             │   │   │   │   │       │   ├── L2a1c3 -3004.2999999999993
#             │   │   │   │   │       │   │   ├── L2a1c3a -3029.7999999999993
#             │   │   │   │   │       │   │   │   └── L2a1c3a1 -3098.999999999999
#             │   │   │   │   │       │   │   └── L2a1c3b -3029.7999999999993
#             │   │   │   │   │       │   │       ├── L2a1c3b1 -3055.2999999999993
#             │   │   │   │   │       │   │       └── L2a1c3b2 -3080.7999999999993
#             │   │   │   │   │       │   ├── L2a1c4 -3004.2999999999993
#             │   │   │   │   │       │   │   └── L2a1c4a -3029.7999999999993
#             │   │   │   │   │       │   │       └── L2a1c4a1 -3055.2999999999993
#             │   │   │   │   │       │   └── - -3004.2999999999993
#             │   │   │   │   │       │       └── L2a1c5 -3029.7999999999993
#             │   │   │   │   │       ├── - -2978.7999999999993
#             │   │   │   │   │       │   ├── L2a1d -3105.2999999999993
#             │   │   │   │   │       │   │   ├── L2a1d1 -3207.2999999999993
#             │   │   │   │   │       │   │   └── L2a1d2 -3130.7999999999993
#             │   │   │   │   │       │   └── L2a1h -3055.2999999999993
#             │   │   │   │   │       ├── L2a1e -3055.2999999999993
#             │   │   │   │   │       │   └── L2a1e1 -3106.2999999999993
#             │   │   │   │   │       └── - -2978.7999999999993
#             │   │   │   │   │           ├── - -2978.7999999999993
#             │   │   │   │   │           │   ├── L2a1i -3029.7999999999993
#             │   │   │   │   │           │   │   └── L2a1i1 -3055.2999999999993
#             │   │   │   │   │           │   └── L2a1q -3055.2999999999993
#             │   │   │   │   │           ├── L2a1j -3029.7999999999993
#             │   │   │   │   │           ├── L2a1k -3004.2999999999993
#             │   │   │   │   │           ├── L2a1l -2999.2999999999993
#             │   │   │   │   │           │   ├── L2a1l1 -3024.7999999999993
#             │   │   │   │   │           │   │   ├── L2a1l1a -3024.7999999999993
#             │   │   │   │   │           │   │   │   ├── L2a1l1a1 -3050.2999999999993
#             │   │   │   │   │           │   │   │   └── L2a1l1a2 -3050.2999999999993
#             │   │   │   │   │           │   │   └── L2a1l1b -3024.7999999999993
#             │   │   │   │   │           │   ├── L2a1l2 -3024.7999999999993
#             │   │   │   │   │           │   │   └── L2a1l2a -3050.2999999999993
#             │   │   │   │   │           │   │       └── L2a1l2a1 -3050.2999999999993
#             │   │   │   │   │           │   └── L2a1l3 -2999.2999999999993
#             │   │   │   │   │           ├── L2a1m -3004.2999999999993
#             │   │   │   │   │           │   └── L2a1m1 -3004.2999999999993
#             │   │   │   │   │           │       └── L2a1m1a -3029.7999999999993
#             │   │   │   │   │           ├── L2a1n -3004.2999999999993
#             │   │   │   │   │           ├── L2a1o -3004.2999999999993
#             │   │   │   │   │           └── L2a1p -3029.7999999999993
#             │   │   │   │   └── L2a2'3'4 -2935.2999999999993
#             │   │   │   │       ├── L2a2'3 -2985.1999999999994
#             │   │   │   │       │   ├── L2a2 -2985.1999999999994
#             │   │   │   │       │   │   ├── L2a2a -3036.1999999999994
#             │   │   │   │       │   │   │   └── L2a2a1 -3061.6999999999994
#             │   │   │   │       │   │   └── L2a2b -3010.6999999999994
#             │   │   │   │       │   │       ├── L2a2b1 -3036.1999999999994
#             │   │   │   │       │   │       │   └── L2a2b1a -3087.1999999999994
#             │   │   │   │       │   │       └── L2a2b2 -3080.5999999999995
#             │   │   │   │       │   └── L2a3 -3080.899999999999
#             │   │   │   │       └── L2a4 -3052.9999999999995
#             │   │   │   │           ├── L2a4a -3205.9999999999995
#             │   │   │   │           └── L2a4b -3180.4999999999995
#             │   │   │   └── L2a5 -2960.7999999999993
#             │   │   └── L2b'c'd -2782.2999999999993
#             │   │       ├── L2b'c -2927.999999999999
#             │   │       │   ├── L2b -3227.2999999999993
#             │   │       │   │   ├── L2b1 -3349.0999999999995
#             │   │       │   │   │   ├── L2b1a -3374.5999999999995
#             │   │       │   │   │   │   ├── L2b1a2 -3400.0999999999995
#             │   │       │   │   │   │   ├── L2b1a3 -3400.0999999999995
#             │   │       │   │   │   │   └── L2b1a4 -3374.5999999999995
#             │   │       │   │   │   └── L2b1b -3374.5999999999995
#             │   │       │   │   ├── L2b2 -3278.2999999999993
#             │   │       │   │   │   └── L2b2a -3430.1999999999994
#             │   │       │   │   └── L2b3 -3227.2999999999993
#             │   │       │   │       ├── L2b3a -3354.7999999999993
#             │   │       │   │       ├── L2b3b -3227.2999999999993
#             │   │       │   │       └── L2b3c -3252.7999999999993
#             │   │       │   └── L2c -3071.5999999999995
#             │   │       │       ├── L2c1 -3097.0999999999995
#             │   │       │       │   └── L2c1a -3097.0999999999995
#             │   │       │       ├── L2c2 -3097.0999999999995
#             │   │       │       │   ├── L2c2a -3122.5999999999995
#             │   │       │       │   │   └── L2c2a1 -3199.0999999999995
#             │   │       │       │   └── L2c2b -3115.1999999999994
#             │   │       │       │       ├── L2c2b1 -3140.6999999999994
#             │   │       │       │       │   ├── L2c2b1a -3166.1999999999994
#             │   │       │       │       │   └── L2c2b1b -3217.1999999999994
#             │   │       │       │       └── L2c2b2 -3140.6999999999994
#             │   │       │       ├── L2c3 -3091.8999999999996
#             │   │       │       │   └── L2c3a -3142.8999999999996
#             │   │       │       ├── L2c4 -3071.5999999999995
#             │   │       │       └── L2c5 -3097.0999999999995
#             │   │       └── L2d -3133.6999999999994
#             │   │           └── - -3133.6999999999994
#             │   │               └── L2d1 -3159.1999999999994
#             │   │                   └── L2d1a -3210.1999999999994
#             │   └── L2e -3341.7999999999993
#             │       └── L2e1 -3367.2999999999993
#             │           └── L2e1a -3418.2999999999993
#             └── L3'4'6 -2662.0999999999995
#                 ├── L6 -3068.9999999999995
#                 │   ├── L6a -3087.7999999999997
#                 │   └── L6b -3068.9999999999995
#                 └── L3'4 -2713.0999999999995
#                     ├── L4 -2738.5999999999995
#                     │   ├── L4a -2884.2999999999993
#                     │   │   ├── L4a1 -3056.5999999999995
#                     │   │   │   └── L4a1a -3107.5999999999995
#                     │   │   └── L4a2 -2935.2999999999993
#                     │   └── L4b -2788.4999999999995
#                     │       ├── L4b1 -2825.4999999999995
#                     │       │   └── L4b1a -3202.7999999999997
#                     │       └── L4b2 -2985.8999999999996
#                     │           ├── L4b2a -2985.8999999999996
#                     │           │   ├── L4b2a1 -3031.4999999999995
#                     │           │   └── L4b2a2 -3062.3999999999996
#                     │           │       ├── L4b2a2a -3138.8999999999996
#                     │           │       ├── L4b2a2b -3138.8999999999996
#                     │           │       └── L4b2a2c -3113.3999999999996
#                     │           └── L4b2b -3087.8999999999996
#                     │               └── L4b2b1 -3175.9999999999995
#                     └── L3 -2764.0999999999995
#                         ├── L3a -2807.7999999999993
#                         │   ├── L3a1 -2880.6999999999994
#                         │   │   ├── L3a1a -2880.6999999999994
#                         │   │   └── L3a1b -3000.899999999999
#                         │   └── - -2832.1999999999994
#                         │       └── L3a2 -2857.6999999999994
#                         │           └── L3a2a -2908.6999999999994
#                         ├── L3b'f -2764.0999999999995
#                         │   ├── L3b -2942.5999999999995
#                         │   │   ├── L3b1 -2942.5999999999995
#                         │   │   │   ├── L3b1a -2968.0999999999995
#                         │   │   │   │   ├── L3b1a1 -2993.5999999999995
#                         │   │   │   │   │   └── L3b1a1a -3019.0999999999995
#                         │   │   │   │   ├── L3b1a2 -2993.5999999999995
#                         │   │   │   │   ├── L3b1a3 -2968.0999999999995
#                         │   │   │   │   ├── L3b1a4 -3019.0999999999995
#                         │   │   │   │   ├── L3b1a5 -2968.0999999999995
#                         │   │   │   │   │   └── L3b1a5a -2993.5999999999995
#                         │   │   │   │   ├── - -2968.0999999999995
#                         │   │   │   │   │   └── L3b1a6 -3044.5999999999995
#                         │   │   │   │   ├── - -2968.0999999999995
#                         │   │   │   │   │   ├── L3b1a7 -3067.1999999999994
#                         │   │   │   │   │   │   └── L3b1a7a -3092.6999999999994
#                         │   │   │   │   │   ├── L3b1a8 -2993.5999999999995
#                         │   │   │   │   │   └── L3b1a9 -2993.5999999999995
#                         │   │   │   │   │       └── L3b1a9a -3019.0999999999995
#                         │   │   │   │   ├── L3b1a10 -3019.0999999999995
#                         │   │   │   │   └── L3b1a11 -2993.5999999999995
#                         │   │   │   └── L3b1b -2993.5999999999995
#                         │   │   │       └── L3b1b1 -3012.2999999999993
#                         │   │   ├── L3b2 -2968.0999999999995
#                         │   │   │   ├── L3b2a -2968.0999999999995
#                         │   │   │   └── L3b2b -3019.0999999999995
#                         │   │   └── L3b3 -3080.7999999999993
#                         │   └── L3f -2866.0999999999995
#                         │       ├── L3f1 -2917.0999999999995
#                         │       │   ├── L3f1a -3043.5999999999995
#                         │       │   │   └── L3f1a1 -3094.5999999999995
#                         │       │   └── L3f1b -3011.6999999999994
#                         │       │       ├── - -3037.1999999999994
#                         │       │       │   ├── L3f1b1 -3062.6999999999994
#                         │       │       │   │   └── L3f1b1a -3113.6999999999994
#                         │       │       │   │       └── L3f1b1a1 -3132.399999999999
#                         │       │       │   ├── L3f1b2 -3037.1999999999994
#                         │       │       │   │   └── L3f1b2a -3062.6999999999994
#                         │       │       │   ├── - -3055.399999999999
#                         │       │       │   │   ├── L3f1b3 -3104.899999999999
#                         │       │       │   │   └── L3f1b4 -3080.899999999999
#                         │       │       │   │       ├── L3f1b4a -3106.399999999999
#                         │       │       │   │       │   └── L3f1b4a1 -3131.899999999999
#                         │       │       │   │       ├── L3f1b4b -3106.399999999999
#                         │       │       │   │       └── L3f1b4c -3106.399999999999
#                         │       │       │   └── L3f1b5 -3062.6999999999994
#                         │       │       └── L3f1b6 -3011.6999999999994
#                         │       ├── L3f2 -2866.0999999999995
#                         │       │   ├── L3f2a -2891.5999999999995
#                         │       │   │   └── L3f2a1 -2968.0999999999995
#                         │       │   │       └── L3f2a1a -2993.5999999999995
#                         │       │   └── L3f2b -2968.0999999999995
#                         │       └── L3f3 -3062.0999999999995
#                         │           ├── L3f3a -3087.5999999999995
#                         │           └── L3f3b -3087.5999999999995
#                         ├── L3c'd -2764.0999999999995
#                         │   ├── L3c -3093.0999999999995
#                         │   └── L3d -2866.0999999999995
#                         │       └── L3d1'2'3'4'5'6 -2891.5999999999995
#                         │           ├── L3d1 -2917.0999999999995
#                         │           │   ├── L3d1a -2968.0999999999995
#                         │           │   │   └── L3d1a1'2 -2993.5999999999995
#                         │           │   │       ├── L3d1a1 -3019.0999999999995
#                         │           │   │       │   ├── L3d1a1a -3062.7999999999993
#                         │           │   │       │   │   └── L3d1a1a1 -3037.2999999999993
#                         │           │   │       │   └── L3d1a1b -3121.0999999999995
#                         │           │   │       └── L3d1a2 -3019.0999999999995
#                         │           │   ├── L3d1b -2942.5999999999995
#                         │           │   │   ├── L3d1b1 -2942.5999999999995
#                         │           │   │   │   ├── L3d1b1a -2968.0999999999995
#                         │           │   │   │   └── L3d1b1b -2986.2999999999993
#                         │           │   │   ├── L3d1b2 -3011.7999999999993
#                         │           │   │   └── L3d1b3 -2993.5999999999995
#                         │           │   │       └── L3d1b3a -3019.0999999999995
#                         │           │   ├── L3d1c -3070.0999999999995
#                         │           │   │   └── L3d1c1 -3121.0999999999995
#                         │           │   └── L3d1d -2968.0999999999995
#                         │           ├── L3d2 -2968.0999999999995
#                         │           │   ├── L3d2a -2968.0999999999995
#                         │           │   └── L3d2b -2968.0999999999995
#                         │           ├── L3d3 -2942.5999999999995
#                         │           │   ├── L3d3a -2993.5999999999995
#                         │           │   │   └── L3d3a1 -3019.0999999999995
#                         │           │   │       ├── L3d3a1a -3044.5999999999995
#                         │           │   │       └── L3d3a1b -3019.0999999999995
#                         │           │   └── L3d3b -2968.0999999999995
#                         │           ├── L3d4 -2909.6999999999994
#                         │           │   └── L3d4a -2960.6999999999994
#                         │           ├── L3d5 -2942.5999999999995
#                         │           │   └── L3d5a -2993.5999999999995
#                         │           └── L3d6 -2968.0999999999995
#                         ├── L3e'i'k'x -2807.7999999999993
#                         │   ├── L3e -2858.7999999999993
#                         │   │   ├── L3e1 -2997.6999999999994
#                         │   │   │   ├── L3e1a -3023.1999999999994
#                         │   │   │   │   ├── L3e1a1 -3066.7999999999993
#                         │   │   │   │   │   └── L3e1a1a -3092.2999999999993
#                         │   │   │   │   ├── L3e1a2 -3169.4999999999995
#                         │   │   │   │   └── L3e1a3 -3023.1999999999994
#                         │   │   │   │       ├── L3e1a3a -3074.1999999999994
#                         │   │   │   │       └── L3e1a3b -3074.1999999999994
#                         │   │   │   ├── L3e1b -3023.1999999999994
#                         │   │   │   │   ├── L3e1b1 -3048.6999999999994
#                         │   │   │   │   └── L3e1b2 -3066.7999999999993
#                         │   │   │   ├── L3e1c -3074.1999999999994
#                         │   │   │   ├── L3e1d -3023.1999999999994
#                         │   │   │   │   └── L3e1d1 -3099.6999999999994
#                         │   │   │   │       └── L3e1d1a -3125.1999999999994
#                         │   │   │   ├── L3e1e -3023.1999999999994
#                         │   │   │   │   ├── L3e1e1 -3048.6999999999994
#                         │   │   │   │   └── L3e1e2 -3110.399999999999
#                         │   │   │   ├── L3e1f -2997.6999999999994
#                         │   │   │   │   ├── L3e1f1 -2997.6999999999994
#                         │   │   │   │   │   └── L3e1f1a -3048.6999999999994
#                         │   │   │   │   └── L3e1f2 -3067.4999999999995
#                         │   │   │   └── L3e1g -3201.6999999999994
#                         │   │   ├── L3e2 -2884.2999999999993
#                         │   │   │   ├── L3e2a -2935.2999999999993
#                         │   │   │   │   ├── L3e2a1 -2953.499999999999
#                         │   │   │   │   │   ├── L3e2a1a -3055.499999999999
#                         │   │   │   │   │   └── L3e2a1b -2978.999999999999
#                         │   │   │   │   │       ├── L3e2a1b1 -3004.499999999999
#                         │   │   │   │   │       ├── L3e2a1b2 -3004.499999999999
#                         │   │   │   │   │       └── L3e2a1b3 -3004.499999999999
#                         │   │   │   │   ├── L3e2a2 -2960.7999999999993
#                         │   │   │   │   └── L3e2a3 -2960.7999999999993
#                         │   │   │   └── L3e2b -2884.2999999999993
#                         │   │   │       ├── L3e2b1 -2909.7999999999993
#                         │   │   │       │   └── L3e2b1a -2935.2999999999993
#                         │   │   │       │       ├── L3e2b1a1 -2935.2999999999993
#                         │   │   │       │       └── L3e2b1a2 -2960.7999999999993
#                         │   │   │       ├── L3e2b2 -2884.2999999999993
#                         │   │   │       ├── - -2884.2999999999993
#                         │   │   │       │   ├── L3e2b3 -2909.7999999999993
#                         │   │   │       │   ├── L3e2b4 -2884.2999999999993
#                         │   │   │       │   ├── L3e2b5 -2909.7999999999993
#                         │   │   │       │   └── L3e2b6 -2909.7999999999993
#                         │   │   │       ├── L3e2b7 -2909.7999999999993
#                         │   │   │       └── L3e2b8 -2884.2999999999993
#                         │   │   └── L3e3'4'5 -2884.0999999999995
#                         │   │       ├── L3e3'4 -2909.5999999999995
#                         │   │       │   ├── L3e3 -3011.5999999999995
#                         │   │       │   │   ├── L3e3a -3037.0999999999995
#                         │   │       │   │   └── L3e3b -3139.0999999999995
#                         │   │       │   │       ├── L3e3b1 -3164.5999999999995
#                         │   │       │   │       ├── L3e3b2 -3164.5999999999995
#                         │   │       │   │       └── L3e3b3 -3139.0999999999995
#                         │   │       │   └── L3e4 -3037.0999999999995
#                         │   │       │       └── L3e4a -3062.5999999999995
#                         │   │       │           └── L3e4a1 -3062.5999999999995
#                         │   │       └── L3e5 -2884.0999999999995
#                         │   │           ├── L3e5a -2884.0999999999995
#                         │   │           │   └── L3e5a1 -2909.5999999999995
#                         │   │           │       └── L3e5a1a -2929.4999999999995
#                         │   │           ├── L3e5b -2884.0999999999995
#                         │   │           ├── - -2884.0999999999995
#                         │   │           │   └── L3e5c -2909.5999999999995
#                         │   │           ├── L3e5d -2909.5999999999995
#                         │   │           ├── L3e5e -2935.0999999999995
#                         │   │           └── L3e5f -2935.0999999999995
#                         │   ├── L3i -2833.2999999999993
#                         │   │   ├── L3i1 -2909.7999999999993
#                         │   │   │   ├── L3i1a -2935.2999999999993
#                         │   │   │   └── L3i1b -2935.2999999999993
#                         │   │   └── L3i2 -2978.899999999999
#                         │   ├── L3k -2999.9999999999995
#                         │   │   └── L3k1 -3104.4999999999995
#                         │   └── L3x -2960.7999999999993
#                         │       ├── L3x1 -2979.5999999999995
#                         │       │   ├── L3x1a -2979.5999999999995
#                         │       │   │   ├── L3x1a1 -2997.6999999999994
#                         │       │   │   └── L3x1a2 -3005.0999999999995
#                         │       │   └── - -2979.5999999999995
#                         │       │       └── L3x1b -3005.0999999999995
#                         │       └── L3x2 -3032.0999999999995
#                         │           ├── L3x2a -3083.0999999999995
#                         │           │   └── L3x2a1 -3134.0999999999995
#                         │           │       └── L3x2a1a -3210.5999999999995
#                         │           └── L3x2b -3131.7999999999993
#                         ├── L3h -2815.0999999999995
#                         │   ├── L3h1 -2942.5999999999995
#                         │   │   ├── L3h1a -2942.5999999999995
#                         │   │   │   ├── L3h1a1 -3095.5999999999995
#                         │   │   │   └── L3h1a2 -2968.0999999999995
#                         │   │   │       ├── L3h1a2a -3146.5999999999995
#                         │   │   │       │   └── L3h1a2a1 -3197.5999999999995
#                         │   │   │       └── L3h1a2b -2993.5999999999995
#                         │   │   └── L3h1b -2942.5999999999995
#                         │   │       ├── L3h1b1 -2968.0999999999995
#                         │   │       │   └── L3h1b1a -2993.5999999999995
#                         │   │       └── L3h1b2 -3134.7999999999993
#                         │   └── L3h2 -3139.2999999999993
#                         ├── M -2815.0999999999995
#                         │   ├── M1'20'51 -2840.5999999999995
#                         │   │   ├── M1 -2917.0999999999995
#                         │   │   │   ├── M1a -2942.5999999999995
#                         │   │   │   │   ├── M1a1 -2968.0999999999995
#                         │   │   │   │   │   ├── M1a1a -2993.5999999999995
#                         │   │   │   │   │   │   └── M1a1a1 -3044.5999999999995
#                         │   │   │   │   │   ├── M1a1b -2993.5999999999995
#                         │   │   │   │   │   │   ├── M1a1b1 -2993.5999999999995
#                         │   │   │   │   │   │   │   ├── M1a1b1a -3019.0999999999995
#                         │   │   │   │   │   │   │   ├── M1a1b1b -2993.5999999999995
#                         │   │   │   │   │   │   │   │   └── M1a1b1b1 -2993.5999999999995
#                         │   │   │   │   │   │   │   └── M1a1b1c -3038.5999999999995
#                         │   │   │   │   │   │   └── M1a1b2 -2993.5999999999995
#                         │   │   │   │   │   ├── - -2993.5999999999995
#                         │   │   │   │   │   │   ├── M1a1c -3095.5999999999995
#                         │   │   │   │   │   │   └── M1a1d -3037.2999999999993
#                         │   │   │   │   │   ├── M1a1e -2968.0999999999995
#                         │   │   │   │   │   │   ├── M1a1e1 -2993.5999999999995
#                         │   │   │   │   │   │   └── M1a1e2 -2968.0999999999995
#                         │   │   │   │   │   ├── M1a1f -2968.0999999999995
#                         │   │   │   │   │   ├── M1a1g -3070.0999999999995
#                         │   │   │   │   │   ├── M1a1h -2993.5999999999995
#                         │   │   │   │   │   └── M1a1i -3029.2999999999997
#                         │   │   │   │   ├── M1a2 -2968.0999999999995
#                         │   │   │   │   │   ├── M1a2a -2968.0999999999995
#                         │   │   │   │   │   └── M1a2b -3014.4999999999995
#                         │   │   │   │   ├── M1a3 -2993.5999999999995
#                         │   │   │   │   │   ├── M1a3a -3019.0999999999995
#                         │   │   │   │   │   └── M1a3b -2993.5999999999995
#                         │   │   │   │   │       ├── M1a3b1 -3044.5999999999995
#                         │   │   │   │   │       └── M1a3b2 -2993.5999999999995
#                         │   │   │   │   ├── M1a4 -2993.5999999999995
#                         │   │   │   │   │   └── M1a4a -2993.5999999999995
#                         │   │   │   │   ├── M1a5 -3095.5999999999995
#                         │   │   │   │   ├── M1a6 -2968.0999999999995
#                         │   │   │   │   ├── M1a7 -2942.5999999999995
#                         │   │   │   │   └── M1a8 -2968.0999999999995
#                         │   │   │   │       └── M1a8a -3019.0999999999995
#                         │   │   │   └── M1b -2917.0999999999995
#                         │   │   │       ├── M1b1 -3013.3999999999996
#                         │   │   │       │   ├── M1b1a -3057.7
#                         │   │   │       │   └── M1b1b -3064.3999999999996
#                         │   │   │       └── M1b2 -2968.0999999999995
#                         │   │   │           ├── M1b2a -2993.5999999999995
#                         │   │   │           ├── M1b2b -3019.0999999999995
#                         │   │   │           └── M1b2c -2993.5999999999995
#                         │   │   ├── M20 -3191.3999999999996
#                         │   │   └── M51 -2986.2999999999993
#                         │   │       ├── M51a -3011.7999999999993
#                         │   │       │   ├── M51a1 -3039.7999999999993
#                         │   │       │   │   ├── M51a1a -3159.899999999999
#                         │   │       │   │   └── M51a1b -3218.2999999999993
#                         │   │       │   └── M51a2 -3113.7999999999993
#                         │   │       └── M51b -3011.7999999999993
#                         │   │           └── M51b1 -3062.7999999999993
#                         │   │               ├── M51b1a -3088.2999999999993
#                         │   │               └── M51b1b -3190.2999999999993
#                         │   ├── M2 -2936.6999999999994
#                         │   │   ├── M2a'b -2987.6999999999994
#                         │   │   │   ├── M2a -3038.6999999999994
#                         │   │   │   │   ├── M2a1 -3159.4999999999995
#                         │   │   │   │   │   ├── M2a1a -3159.4999999999995
#                         │   │   │   │   │   │   ├── M2a1a1 -3184.9999999999995
#                         │   │   │   │   │   │   │   ├── M2a1a1a -3210.4999999999995
#                         │   │   │   │   │   │   │   │   └── M2a1a1a1 -3235.9999999999995
#                         │   │   │   │   │   │   │   └── M2a1a1b -3184.9999999999995
#                         │   │   │   │   │   │   │       └── M2a1a1b1 -3210.4999999999995
#                         │   │   │   │   │   │   ├── M2a1a2 -3159.4999999999995
#                         │   │   │   │   │   │   │   └── M2a1a2a -3184.9999999999995
#                         │   │   │   │   │   │   │       └── M2a1a2a1 -3210.4999999999995
#                         │   │   │   │   │   │   │           └── M2a1a2a1a -3210.4999999999995
#                         │   │   │   │   │   │   └── - -3178.2999999999997
#                         │   │   │   │   │   │       └── M2a1a3 -3196.4999999999995
#                         │   │   │   │   │   │           └── - -3221.9999999999995
#                         │   │   │   │   │   │               ├── M2a1a3a -3247.4999999999995
#                         │   │   │   │   │   │               │   └── M2a1a3a1 -3247.4999999999995
#                         │   │   │   │   │   │               └── M2a1a3b -3247.4999999999995
#                         │   │   │   │   │   ├── M2a1b -3286.9999999999995
#                         │   │   │   │   │   └── M2a1c -3196.9999999999995
#                         │   │   │   │   ├── M2a2 -3089.6999999999994
#                         │   │   │   │   │   └── M2a2a -3140.6999999999994
#                         │   │   │   │   └── M2a3 -3064.1999999999994
#                         │   │   │   │       └── M2a3a -3064.1999999999994
#                         │   │   │   └── M2b -3140.6999999999994
#                         │   │   │       ├── M2b1 -3166.1999999999994
#                         │   │   │       │   ├── M2b1a -3312.399999999999
#                         │   │   │       │   └── M2b1b -3359.6999999999994
#                         │   │   │       ├── M2b2 -3166.1999999999994
#                         │   │   │       ├── M2b3 -3140.6999999999994
#                         │   │   │       │   └── M2b3a -3166.1999999999994
#                         │   │   │       └── M2b4 -3217.1999999999994
#                         │   │   └── M2c -3038.6999999999994
#                         │   ├── M3 -2815.0999999999995
#                         │   │   ├── M3a -2840.5999999999995
#                         │   │   │   ├── M3a1 -2866.0999999999995
#                         │   │   │   │   └── - -2884.8999999999996
#                         │   │   │   │       ├── M3a1a -2910.3999999999996
#                         │   │   │   │       └── M3a1b -2910.3999999999996
#                         │   │   │   └── M3a2 -2891.5999999999995
#                         │   │   │       └── M3a2a -2960.7999999999993
#                         │   │   ├── M3b -2891.5999999999995
#                         │   │   ├── M3c -2840.5999999999995
#                         │   │   │   ├── - -2840.5999999999995
#                         │   │   │   │   └── M3c1 -2917.0999999999995
#                         │   │   │   │       ├── M3c1a -2942.5999999999995
#                         │   │   │   │       └── M3c1b -2993.5999999999995
#                         │   │   │   │           └── M3c1b1 -3019.0999999999995
#                         │   │   │   │               ├── M3c1b1a -3070.0999999999995
#                         │   │   │   │               └── M3c1b1b -3044.5999999999995
#                         │   │   │   └── M3c2 -2866.0999999999995
#                         │   │   └── M3d -2840.5999999999995
#                         │   │       └── M3d1 -2866.0999999999995
#                         │   │           └── M3d1a -2866.0999999999995
#                         │   │               └── M3d1a1 -2891.5999999999995
#                         │   ├── M467 -2840.5999999999995
#                         │   │   ├── - -2840.5999999999995
#                         │   │   │   ├── M4 -2942.5999999999995
#                         │   │   │   │   ├── M4a -2968.0999999999995
#                         │   │   │   │   └── M4b -2968.0999999999995
#                         │   │   │   ├── M65 -2840.5999999999995
#                         │   │   │   │   ├── M65a -2917.0999999999995
#                         │   │   │   │   │   ├── M65a1 -2993.5999999999995
#                         │   │   │   │   │   └── - -2917.0999999999995
#                         │   │   │   │   │       └── M65a2 -2942.5999999999995
#                         │   │   │   │   └── M65b -2910.4999999999995
#                         │   │   │   └── M67 -3088.0999999999995
#                         │   │   ├── M18'38 -2859.4999999999995
# ...
#                                                 │       │   │   ├── K1a4 -3192.3999999999996
#                                                 │       │   │   │   ├── K1a4a -3217.8999999999996
#                                                 │       │   │   │   │   └── K1a4a1 -3243.3999999999996
#                                                 │       │   │   │   │       ├── K1a4a1a -3268.8999999999996
#                                                 │       │   │   │   │       │   ├── - -3268.8999999999996
#                                                 │       │   │   │   │       │   │   ├── K1a4a1a1 -3294.3999999999996
#                                                 │       │   │   │   │       │   │   └── K1a4a1a3 -3268.8999999999996
#                                                 │       │   │   │   │       │   └── K1a4a1a2 -3294.3999999999996
#                                                 │       │   │   │   │       │       ├── K1a4a1a2a -3319.8999999999996
#                                                 │       │   │   │   │       │       └── K1a4a1a2b -3294.3999999999996
#                                                 │       │   │   │   │       ├── K1a4a1b -3243.3999999999996
#                                                 │       │   │   │   │       │   ├── K1a4a1b1 -3268.8999999999996
#                                                 │       │   │   │   │       │   └── K1a4a1b2 -3268.8999999999996
#                                                 │       │   │   │   │       ├── K1a4a1c -3268.8999999999996
#                                                 │       │   │   │   │       │   └── K1a4a1c1 -3268.8999999999996
#                                                 │       │   │   │   │       ├── K1a4a1d -3268.8999999999996
#                                                 │       │   │   │   │       ├── K1a4a1e -3243.3999999999996
#                                                 │       │   │   │   │       ├── K1a4a1f -3288.2
#                                                 │       │   │   │   │       │   └── K1a4a1f1 -3332.3999999999996
#                                                 │       │   │   │   │       ├── K1a4a1g -3294.3999999999996
#                                                 │       │   │   │   │       ├── K1a4a1h -3243.3999999999996
#                                                 │       │   │   │   │       └── K1a4a1i -3243.3999999999996
#                                                 │       │   │   │   ├── K1a4b -3236.9999999999995
#                                                 │       │   │   │   │   └── K1a4b1 -3313.4999999999995
#                                                 │       │   │   │   ├── K1a4c -3243.3999999999996
#                                                 │       │   │   │   │   └── K1a4c1 -3319.8999999999996
#                                                 │       │   │   │   ├── K1a4d -3239.7999999999997
#                                                 │       │   │   │   ├── K1a4e -3192.3999999999996
#                                                 │       │   │   │   ├── K1a4f -3217.8999999999996
#                                                 │       │   │   │   │   └── K1a4f1 -3243.3999999999996
#                                                 │       │   │   │   ├── K1a4g -3217.8999999999996
#                                                 │       │   │   │   ├── K1a4h -3217.8999999999996
#                                                 │       │   │   │   │   └── K1a4h1 -3243.3999999999996
#                                                 │       │   │   │   ├── K1a4i -3192.3999999999996
#                                                 │       │   │   │   └── - -3192.3999999999996
#                                                 │       │   │   │       └── K1a4j -3192.3999999999996
#                                                 │       │   │   │           └── K1a4j1 -3217.8999999999996
#                                                 │       │   │   ├── K1a5 -3192.3999999999996
#                                                 │       │   │   │   ├── K1a5a -3243.3999999999996
#                                                 │       │   │   │   └── K1a5b -3255.9999999999995
#                                                 │       │   │   ├── K1a6 -3243.3999999999996
#                                                 │       │   │   ├── K1a7 -3186.7999999999997
#                                                 │       │   │   ├── K1a8 -3183.7
#                                                 │       │   │   │   ├── K1a8a -3234.7
#                                                 │       │   │   │   │   └── K1a8a1 -3260.2
#                                                 │       │   │   │   └── K1a8b -3209.2
#                                                 │       │   │   ├── - -3166.8999999999996
#                                                 │       │   │   │   ├── K1a9 -3192.3999999999996
#                                                 │       │   │   │   ├── K1a10 -3192.3999999999996
#                                                 │       │   │   │   │   └── K1a10a -3217.8999999999996
#                                                 │       │   │   │   ├── K1a13 -3217.8999999999996
#                                                 │       │   │   │   │   └── K1a13a -3243.3999999999996
#                                                 │       │   │   │   ├── K1a14 -3243.3999999999996
#                                                 │       │   │   │   ├── K1a15 -3192.3999999999996
#                                                 │       │   │   │   ├── K1a16 -3192.3999999999996
#                                                 │       │   │   │   └── K1a26 -3192.3999999999996
#                                                 │       │   │   ├── - -3185.0999999999995
#                                                 │       │   │   │   ├── K1a11 -3221.5999999999995
#                                                 │       │   │   │   │   ├── K1a11a -3247.0999999999995
#                                                 │       │   │   │   │   │   └── K1a11a1 -3272.5999999999995
#                                                 │       │   │   │   │   └── K1a11b -3247.0999999999995
#                                                 │       │   │   │   ├── K1a24 -3210.5999999999995
#                                                 │       │   │   │   │   └── K1a24a -3287.0999999999995
#                                                 │       │   │   │   ├── K1a30 -3185.0999999999995
#                                                 │       │   │   │   │   └── K1a30a -3185.0999999999995
#                                                 │       │   │   │   └── K1a31 -3185.0999999999995
#                                                 │       │   │   ├── K1a12 -3166.8999999999996
#                                                 │       │   │   │   └── K1a12a -3192.3999999999996
#                                                 │       │   │   │       └── K1a12a1 -3217.8999999999996
#                                                 │       │   │   │           └── K1a12a1a -3243.3999999999996
#                                                 │       │   │   ├── K1a17 -3192.3999999999996
#                                                 │       │   │   │   └── K1a17a -3243.3999999999996
#                                                 │       │   │   ├── K1a18 -3217.8999999999996
#                                                 │       │   │   ├── K1a19 -3166.8999999999996
#                                                 │       │   │   │   └── K1a19a -3310.4999999999995
#                                                 │       │   │   ├── K1a23 -3166.8999999999996
#                                                 │       │   │   ├── K1a25 -3217.8999999999996
#                                                 │       │   │   ├── K1a27 -3217.8999999999996
#                                                 │       │   │   ├── K1a28 -3212.2
#                                                 │       │   │   └── K1a29 -3192.3999999999996
#                                                 │       │   │       └── K1a29a -3217.8999999999996
#                                                 │       │   ├── K1b -3172.0999999999995
#                                                 │       │   │   ├── K1b1 -3197.5999999999995
#                                                 │       │   │   │   ├── - -3197.5999999999995
#                                                 │       │   │   │   │   ├── K1b1a -3299.5999999999995
#                                                 │       │   │   │   │   │   ├── K1b1a1 -3325.0999999999995
#                                                 │       │   │   │   │   │   │   ├── - -3325.0999999999995
#                                                 │       │   │   │   │   │   │   │   ├── K1b1a1a -3350.5999999999995
#                                                 │       │   │   │   │   │   │   │   └── K1b1a1b -3350.5999999999995
#                                                 │       │   │   │   │   │   │   ├── K1b1a1c -3376.0999999999995
#                                                 │       │   │   │   │   │   │   │   └── K1b1a1c1 -3376.0999999999995
#                                                 │       │   │   │   │   │   │   └── K1b1a1d -3325.0999999999995
#                                                 │       │   │   │   │   │   │       └── K1b1a1d1 -3325.0999999999995
#                                                 │       │   │   │   │   │   └── K1b1a2 -3376.0999999999995
#                                                 │       │   │   │   │   └── K1b1b -3223.0999999999995
#                                                 │       │   │   │   │       └── K1b1b1 -3248.5999999999995
#                                                 │       │   │   │   └── K1b1c -3241.1999999999994
#                                                 │       │   │   └── K1b2 -3172.0999999999995
#                                                 │       │   │       ├── K1b2a -3172.0999999999995
#                                                 │       │   │       │   ├── K1b2a1 -3197.5999999999995
#                                                 │       │   │       │   │   └── K1b2a1a -3223.0999999999995
#                                                 │       │   │       │   │       └── K1b2a1a1 -3248.5999999999995
#                                                 │       │   │       │   ├── K1b2a2 -3172.0999999999995
#                                                 │       │   │       │   │   └── K1b2a2a -3197.5999999999995
#                                                 │       │   │       │   └── K1b2a3 -3197.5999999999995
#                                                 │       │   │       └── K1b2b -3197.5999999999995
#                                                 │       │   │           └── K1b2b1 -3197.5999999999995
#                                                 │       │   ├── K1c -3146.5999999999995
#                                                 │       │   │   ├── K1c1 -3146.5999999999995
#                                                 │       │   │   │   ├── K1c1a -3172.0999999999995
#                                                 │       │   │   │   ├── K1c1b -3172.0999999999995
#                                                 │       │   │   │   ├── K1c1c -3172.0999999999995
#                                                 │       │   │   │   ├── K1c1d -3223.0999999999995
#                                                 │       │   │   │   ├── K1c1e -3172.0999999999995
#                                                 │       │   │   │   ├── K1c1f -3172.0999999999995
#                                                 │       │   │   │   ├── K1c1g -3146.5999999999995
#                                                 │       │   │   │   ├── K1c1h -3172.0999999999995
#                                                 │       │   │   │   └── K1c1i -3172.0999999999995
#                                                 │       │   │   └── K1c2 -3197.5999999999995
#                                                 │       │   │       └── K1c2a -3197.5999999999995
#                                                 │       │   └── - -3172.0999999999995
#                                                 │       │       ├── K1d -3248.5999999999995
#                                                 │       │       │   └── K1d1 -3274.0999999999995
#                                                 │       │       ├── K1e -3223.0999999999995
#                                                 │       │       │   └── K1e1 -3292.2999999999993
#                                                 │       │       └── K1f -3223.0999999999995
#                                                 │       ├── K2 -3146.5999999999995
#                                                 │       │   ├── K2a -3170.9999999999995
#                                                 │       │   │   ├── K2a1 -3247.4999999999995
#                                                 │       │   │   │   └── K2a1a -3272.9999999999995
#                                                 │       │   │   ├── K2a2 -3196.4999999999995
#                                                 │       │   │   │   └── K2a2a -3221.9999999999995
#                                                 │       │   │   │       └── K2a2a1 -3267.7999999999997
#                                                 │       │   │   ├── K2a3 -3170.9999999999995
#                                                 │       │   │   │   └── K2a3a -3196.4999999999995
#                                                 │       │   │   │       └── K2a3a1 -3221.9999999999995
#                                                 │       │   │   ├── K2a4 -3196.4999999999995
#                                                 │       │   │   ├── K2a5 -3190.2999999999997
#                                                 │       │   │   │   ├── K2a5a -3215.7999999999997
#                                                 │       │   │   │   │   └── K2a5a1 -3215.7999999999997
#                                                 │       │   │   │   └── K2a5b -3190.2999999999997
#                                                 │       │   │   ├── K2a6 -3170.9999999999995
#                                                 │       │   │   ├── K2a7 -3196.4999999999995
#                                                 │       │   │   ├── K2a8 -3189.7999999999997
#                                                 │       │   │   ├── K2a9 -3221.9999999999995
#                                                 │       │   │   ├── K2a10 -3196.4999999999995
#                                                 │       │   │   └── K2a11 -3221.9999999999995
#                                                 │       │   ├── K2b -3197.5999999999995
#                                                 │       │   │   ├── K2b1 -3197.5999999999995
#                                                 │       │   │   │   ├── K2b1a -3197.5999999999995
#                                                 │       │   │   │   │   ├── K2b1a1 -3223.0999999999995
#                                                 │       │   │   │   │   │   └── K2b1a1a -3248.5999999999995
#                                                 │       │   │   │   │   ├── K2b1a2 -3223.0999999999995
#                                                 │       │   │   │   │   ├── K2b1a3 -3219.4999999999995
#                                                 │       │   │   │   │   └── K2b1a4 -3241.8999999999996
#                                                 │       │   │   │   └── K2b1b -3274.0999999999995
#                                                 │       │   │   └── K2b2 -3223.0999999999995
#                                                 │       │   └── K2c -3172.0999999999995
#                                                 │       └── K3 -3254.9999999999995
#                                                 └── U8c -3062.7999999999993

# %%
bcf_in = VariantFile("PhyloTree.org-parser/out4.vcf")

# %%
ref = FastaFile('ref.fa')

# %%
callset = allel.read_vcf('PhyloTree.org-parser/out4.vcf', fields=['calldata/PL'])
a = np.asarray(callset['calldata/PL'])
# Out:
# /home/nikita/anaconda3/lib/python3.8/site-packages/allel/io/vcf_read.py:1732: UserWarning: invalid INFO header: '##INFO=<ID=VDB,Number=1,Type=Float,Description="Variant Distance Bias for filtering splice-site artefacts in RNA-seq data (bigger is better)",Version="3">\n'
#   warnings.warn('invalid INFO header: %r' % header)

# %%
def calculate_likelihood(vcf, ref):
    lh = 0
    ref = ref.fetch('chrM')
    gls = get_log_monozygous(vcf)
#     gls[gls<0]=-10**6
    for i in range(len(ref)):
        if ref[i].capitalize() == 'A':
            lh += gls[i,0]
        if ref[i].capitalize() == 'T':
            lh += gls[i,1]
        if ref[i].capitalize() == 'G':
            lh += gls[i,2]
        if ref[i].capitalize() == 'C':
            lh += gls[i,3]
    return lh

# %%
ref_lh = calculate_likelihood(bcf_in,ref)
ref_lh
# Out:
# -2206.2

# %%
def call_likelihood(gls,node,ref,lh=0):
    snps = node.snps
#     gls = get_log_monozygous(vcf)
    for snp in snps:
#       snp = [old, new, pos]
        pos = snp[2]-1
        if snp[1].capitalize() == 'A':
            lh = lh - calculate_pl(gls,ref, pos)+ gls[pos,0]
#             print(1,snp[1].capitalize())
        if snp[1].capitalize() == 'T':
            lh = lh - calculate_pl(gls,ref, pos)+ gls[pos,1]
#             print(2,snp[1].capitalize())
        if snp[1].capitalize() == 'G':
            lh = lh - calculate_pl(gls,ref, pos)+ gls[pos,2]
#             print(3,snp[1].capitalize())
        if snp[1].capitalize() == 'C':
            lh = lh - calculate_pl(gls,ref, pos)+ gls[pos,3]
#             print(4,snp[1].capitalize())
        
    return lh

# %%
def calculate_pl(gls, ref,pos):
    lh = 0
    ref = ref.fetch('chrM')
#     gls = get_log_monozygous(vcf)
    i = pos
    if ref[i].capitalize() == 'A':
        lh += gls[i,0]
    if ref[i].capitalize() == 'T':
        lh += gls[i,1]
    if ref[i].capitalize() == 'G':
        lh += gls[i,2]
    if ref[i].capitalize() == 'C':
        lh += gls[i,3]
    return lh

# %%
def prunung(node,ref,gls):
    if node.parent == None:
        node.lh = ref_lh
    else:
        node.lh = call_likelihood(gls,node,ref,node.parent.lh)
    for i in node.children:
        prunung(i,ref,gls)

# %%
gls = get_log_monozygous(bcf_in)
prunung(a,ref,gls)

# %%
ref.fetch('chrM')[0]
# Out:
# 'G'

# %%
print(RenderTree(a))
# Out:
# mt-MRCA (RSRS) -2206.2
# ├── L0 -2435.7
# │   ├── L0a'b'f'g'k -2486.7
# │   │   ├── L0a'b'f'g -2614.2
# │   │   │   ├── L0a'b'g -2767.2
# │   │   │   │   ├── L0a'g -2818.2
# │   │   │   │   │   ├── L0a -2920.2
# │   │   │   │   │   │   ├── L0a1'4 -2945.7
# │   │   │   │   │   │   │   ├── L0a1 -2971.2
# │   │   │   │   │   │   │   │   ├── L0a1a -2996.7
# │   │   │   │   │   │   │   │   │   └── - -3022.2
# │   │   │   │   │   │   │   │   │       ├── L0a1a1 -3047.7
# │   │   │   │   │   │   │   │   │       ├── L0a1a2 -3047.7
# │   │   │   │   │   │   │   │   │       └── L0a1a3 -3047.7
# │   │   │   │   │   │   │   │   ├── - -2945.7
# │   │   │   │   │   │   │   │   │   ├── L0a1b -2996.7
# │   │   │   │   │   │   │   │   │   │   ├── L0a1b1 -3022.2
# │   │   │   │   │   │   │   │   │   │   │   └── L0a1b1a -3047.7
# │   │   │   │   │   │   │   │   │   │   │       └── L0a1b1a1 -3073.2
# │   │   │   │   │   │   │   │   │   │   │           └── L0a1b1a1a -3124.2
# │   │   │   │   │   │   │   │   │   │   └── L0a1b2 -3073.2
# │   │   │   │   │   │   │   │   │   │       └── L0a1b2a -3098.7
# │   │   │   │   │   │   │   │   │   ├── L0a1c -2971.2
# │   │   │   │   │   │   │   │   │   │   └── L0a1c1 -3022.2
# │   │   │   │   │   │   │   │   │   └── L0a1d -2996.7
# │   │   │   │   │   │   │   │   └── L0a1e -3047.7
# │   │   │   │   │   │   │   └── L0a4 -3328.2
# │   │   │   │   │   │   ├── L0a2 -3072.2
# │   │   │   │   │   │   │   ├── L0a2a -3123.2
# │   │   │   │   │   │   │   │   ├── L0a2a1 -3148.7
# │   │   │   │   │   │   │   │   │   ├── L0a2a1a -3174.2
# │   │   │   │   │   │   │   │   │   │   ├── L0a2a1a1 -3225.2
# │   │   │   │   │   │   │   │   │   │   └── L0a2a1a2 -3225.2
# │   │   │   │   │   │   │   │   │   └── L0a2a1b -3199.7
# │   │   │   │   │   │   │   │   └── L0a2a2 -3225.2
# │   │   │   │   │   │   │   │       └── L0a2a2a -3250.7
# │   │   │   │   │   │   │   │           ├── L0a2a2a1 -3276.2
# │   │   │   │   │   │   │   │           └── L0a2a2a2 -3276.2
# │   │   │   │   │   │   │   ├── L0a2b -3276.2
# │   │   │   │   │   │   │   │   └── L0a2b1 -3301.7
# │   │   │   │   │   │   │   ├── L0a2c -3276.2
# │   │   │   │   │   │   │   └── L0a2d -3123.2
# │   │   │   │   │   │   └── L0a3 -2945.7
# │   │   │   │   │   └── L0g -3379.2
# │   │   │   │   └── L0b -2894.7
# │   │   │   └── L0f -2894.7
# │   │   │       ├── L0f1 -2971.2
# │   │   │       └── L0f2 -2996.7
# │   │   │           ├── L0f2a -3073.2
# │   │   │           │   └── L0f2a1 -3302.7
# │   │   │           └── L0f2b -3557.7
# │   │   └── L0k -3175.2
# │   │       ├── L0k1 -3251.7
# │   │       │   ├── L0k1a -3353.7
# │   │       │   │   ├── L0k1a1 -3379.2
# │   │       │   │   │   ├── L0k1a1a -3430.2
# │   │       │   │   │   ├── L0k1a1b -3404.7
# │   │       │   │   │   ├── L0k1a1c -3404.7
# │   │       │   │   │   └── L0k1a1d -3404.7
# │   │       │   │   ├── L0k1a2 -3379.2
# │   │       │   │   │   └── L0k1a2a -3404.7
# │   │       │   │   └── L0k1a3 -3430.2
# │   │       │   └── L0k1b -3404.7
# │   │       └── L0k2 -3277.2
# │   │           ├── L0k2a -3353.7
# │   │           │   └── L0k2a1 -3379.2
# │   │           │       └── L0k2a1a -3455.7
# │   │           └── L0k2b -3302.7
# │   └── L0d -2690.7
# │       ├── L0d1'2 -2741.7
# │       │   ├── L0d1 -2843.7
# │       │   │   ├── L0d1a'c'd -2869.2
# │       │   │   │   ├── L0d1a'd -2869.2
# │       │   │   │   │   ├── L0d1a -2971.2
# │       │   │   │   │   │   └── L0d1a1 -3022.2
# │       │   │   │   │   │       ├── L0d1a1a -3022.2
# │       │   │   │   │   │       │   ├── L0d1a1a1 -3022.2
# │       │   │   │   │   │       │   ├── L0d1a1a2 -3047.7
# │       │   │   │   │   │       │   └── L0d1a1a3 -3047.7
# │       │   │   │   │   │       ├── L0d1a1b -3073.2
# │       │   │   │   │   │       │   └── L0d1a1b1 -3124.2
# │       │   │   │   │   │       │       ├── L0d1a1b1a -3149.7
# │       │   │   │   │   │       │       └── L0d1a1b1b -3149.7
# │       │   │   │   │   │       ├── L0d1a1c -3124.2
# │       │   │   │   │   │       └── L0d1a1d -3073.2
# │       │   │   │   │   └── L0d1d -3047.7
# │       │   │   │   └── L0d1c -3047.7
# │       │   │   │       ├── L0d1c1 -3098.7
# │       │   │   │       │   └── L0d1c1a -3149.7
# │       │   │   │       │       ├── L0d1c1a1 -3200.7
# │       │   │   │       │       │   ├── L0d1c1a1a -3175.2
# │       │   │   │       │       │   │   ├── L0d1c1a1a1 -3251.7
# │       │   │   │       │       │   │   └── L0d1c1a1a2 -3200.7
# │       │   │   │       │       │   └── L0d1c1a1b -3226.2
# │       │   │   │       │       └── L0d1c1a2 -3226.2
# │       │   │   │       ├── L0d1c2 -3073.2
# │       │   │   │       │   └── L0d1c2a -3175.2
# │       │   │   │       │       └── L0d1c2a1 -3277.2
# │       │   │   │       └── L0d1c3 -3149.7
# │       │   │   └── L0d1b -2869.2
# │       │   │       ├── L0d1b1 -2945.7
# │       │   │       │   ├── L0d1b1a -3073.2
# │       │   │       │   │   └── L0d1b1a1 -3098.7
# │       │   │       │   ├── L0d1b1b -2971.2
# │       │   │       │   │   └── L0d1b1b1 -3022.2
# │       │   │       │   └── - -2945.7
# │       │   │       │       └── L0d1b1c -3073.2
# │       │   │       └── L0d1b2 -2971.2
# │       │   │           ├── L0d1b2a -3073.2
# │       │   │           │   ├── L0d1b2a1 -3098.7
# │       │   │           │   └── L0d1b2a2 -3149.7
# │       │   │           └── L0d1b2b -2945.7
# │       │   │               ├── L0d1b2b1 -2996.7
# │       │   │               │   ├── L0d1b2b1a -3200.7
# │       │   │               │   └── L0d1b2b1b -3073.2
# │       │   │               │       └── L0d1b2b1b1 -3098.7
# │       │   │               └── L0d1b2b2 -2996.7
# │       │   │                   ├── L0d1b2b2a -3022.2
# │       │   │                   ├── L0d1b2b2b -3022.2
# │       │   │                   │   └── L0d1b2b2b1 -3073.2
# │       │   │                   └── L0d1b2b2c -3022.2
# │       │   │                       ├── L0d1b2b2c1 -3047.7
# │       │   │                       └── L0d1b2b2c2 -3047.7
# │       │   └── L0d2 -2894.7
# │       │       ├── L0d2a'b'd -2920.2
# │       │       │   ├── L0d2a -3022.2
# │       │       │   │   ├── L0d2a1 -3175.2
# │       │       │   │   │   ├── L0d2a1a -3200.7
# │       │       │   │   │   │   ├── L0d2a1a1 -3226.2
# │       │       │   │   │   │   │   └── L0d2a1a1a -3200.7
# │       │       │   │   │   │   ├── L0d2a1a2 -3226.2
# │       │       │   │   │   │   └── L0d2a1a3 -3226.2
# │       │       │   │   │   ├── L0d2a1b -3226.2
# │       │       │   │   │   └── L0d2a1c -3277.2
# │       │       │   │   └── L0d2a2 -3226.2
# │       │       │   ├── L0d2b -3047.7
# │       │       │   │   ├── L0d2b1 -3226.2
# │       │       │   │   │   ├── L0d2b1a -3200.7
# │       │       │   │   │   │   └── L0d2b1a1 -3251.7
# │       │       │   │   │   │       └── L0d2b1a1a -3277.2
# │       │       │   │   │   └── L0d2b1b -3302.7
# │       │       │   │   └── L0d2b2 -3149.7
# │       │       │   └── L0d2d -3277.2
# │       │       └── L0d2c -3226.2
# │       │           ├── L0d2c1 -3251.7
# │       │           │   ├── L0d2c1a -3302.7
# │       │           │   │   └── L0d2c1a1 -3404.7
# │       │           │   └── L0d2c1b -3302.7
# │       │           └── L0d2c2 -3328.2
# │       │               ├── L0d2c2a -3353.7
# │       │               │   └── L0d2c2a1 -3379.2
# │       │               │       └── L0d2c2a1a -3430.2
# │       │               └── L0d2c2b -3379.2
# │       └── L0d3 -3149.7
# │           ├── L0d3a -3251.7
# │           └── L0d3b -3302.7
# │               ├── L0d3b1 -3328.2
# │               └── L0d3b2 -3328.2
# └── L1'2'3'4'5'6 -2180.7
#     ├── L1 -2027.6999999999998
#     │   ├── L1b -1517.6999999999998
#     │   │   ├── L1b1 -1645.1999999999998
#     │   │   │   └── L1b1a -1670.6999999999998
#     │   │   │       ├── L1b1a1'4 -1670.6999999999998
#     │   │   │       │   ├── L1b1a1 -1747.1999999999998
#     │   │   │       │   └── L1b1a4 -1696.1999999999998
#     │   │   │       │       └── L1b1a4a -1721.6999999999998
#     │   │   │       ├── L1b1a2 -1696.1999999999998
#     │   │   │       │   └── L1b1a2a -1721.6999999999998
#     │   │   │       ├── - -1645.1999999999998
#     │   │   │       │   ├── L1b1a3 -1670.6999999999998
#     │   │   │       │   │   ├── L1b1a3a -1696.1999999999998
#     │   │   │       │   │   │   └── L1b1a3a1 -1721.6999999999998
#     │   │   │       │   │   └── L1b1a3b -1721.6999999999998
#     │   │   │       │   ├── L1b1a9 -1670.6999999999998
#     │   │   │       │   ├── L1b1a15 -1696.1999999999998
#     │   │   │       │   │   └── L1b1a15a -1721.6999999999998
#     │   │   │       │   ├── L1b1a17 -1670.6999999999998
#     │   │   │       │   └── L1b1a18 -1696.1999999999998
#     │   │   │       ├── L1b1a5 -1696.1999999999998
#     │   │   │       ├── L1b1a6 -1721.6999999999998
#     │   │   │       ├── L1b1a7 -1696.1999999999998
#     │   │   │       │   └── L1b1a7a -1747.1999999999998
#     │   │   │       ├── L1b1a8 -1696.1999999999998
#     │   │   │       ├── L1b1a10 -1696.1999999999998
#     │   │   │       │   ├── L1b1a10a -1721.6999999999998
#     │   │   │       │   └── L1b1a10b -1721.6999999999998
#     │   │   │       ├── L1b1a12 -1721.6999999999998
#     │   │   │       │   ├── L1b1a12a -1747.1999999999998
#     │   │   │       │   └── L1b1a12b -1747.1999999999998
#     │   │   │       ├── L1b1a13 -1696.1999999999998
#     │   │   │       ├── L1b1a14 -1696.1999999999998
#     │   │   │       └── L1b1a16 -1721.6999999999998
#     │   │   └── L1b2'3 -1517.6999999999998
#     │   │       ├── L1b2 -1390.1999999999998
#     │   │       │   └── L1b2a -1441.1999999999998
#     │   │       └── L1b3 -1619.6999999999998
#     │   └── L1c -2384.7
#     │       ├── L1c1'2'4'5'6 -2410.2
#     │       │   ├── L1c1'2'4'6 -2461.2
#     │       │   │   ├── L1c1 -2512.2
#     │       │   │   │   ├── L1c1a'b'd -2537.7
#     │       │   │   │   │   ├── L1c1a -2614.2
#     │       │   │   │   │   │   └── - -2614.2
#     │       │   │   │   │   │       ├── L1c1a1 -2639.7
#     │       │   │   │   │   │       │   ├── L1c1a1a -2767.2
#     │       │   │   │   │   │       │   │   ├── L1c1a1a1 -2920.2
#     │       │   │   │   │   │       │   │   │   ├── L1c1a1a1a -3022.2
#     │       │   │   │   │   │       │   │   │   └── L1c1a1a1b -2971.2
#     │       │   │   │   │   │       │   │   │       └── L1c1a1a1b1 -2996.7
#     │       │   │   │   │   │       │   │   └── L1c1a1a2 -2843.7
#     │       │   │   │   │   │       │   └── L1c1a1b -2869.2
#     │       │   │   │   │   │       └── L1c1a2 -2920.2
#     │       │   │   │   │   │           ├── L1c1a2a -2996.7
#     │       │   │   │   │   │           │   ├── L1c1a2a1 -3022.2
#     │       │   │   │   │   │           │   └── L1c1a2a2 -3022.2
#     │       │   │   │   │   │           ├── L1c1a2b -3022.2
#     │       │   │   │   │   │           └── L1c1a2c -2996.7
#     │       │   │   │   │   └── L1c1b'd -2563.2
#     │       │   │   │   │       ├── L1c1b -2792.7
#     │       │   │   │   │       │   └── L1c1b1 -2894.7
#     │       │   │   │   │       └── L1c1d -2665.2
#     │       │   │   │   │           └── L1c1d1 -2716.2
#     │       │   │   │   └── L1c1c -2690.7
#     │       │   │   ├── L1c2'4 -2512.2
#     │       │   │   │   ├── L1c2 -2818.2
#     │       │   │   │   │   ├── L1c2a -2894.7
#     │       │   │   │   │   │   ├── L1c2a1 -2945.7
#     │       │   │   │   │   │   │   ├── L1c2a1a -3124.2
#     │       │   │   │   │   │   │   └── L1c2a1b -2996.7
#     │       │   │   │   │   │   ├── L1c2a2 -3073.2
#     │       │   │   │   │   │   └── L1c2a3 -2996.7
#     │       │   │   │   │   │       └── L1c2a3a -3124.2
#     │       │   │   │   │   └── L1c2b -2843.7
#     │       │   │   │   │       ├── L1c2b1 -2869.2
#     │       │   │   │   │       │   ├── L1c2b1a'b -2894.7
#     │       │   │   │   │       │   │   ├── L1c2b1a -2971.2
#     │       │   │   │   │       │   │   │   └── L1c2b1a1 -3047.7
#     │       │   │   │   │       │   │   └── L1c2b1b -2996.7
#     │       │   │   │   │       │   │       └── L1c2b1b1 -3073.2
#     │       │   │   │   │       │   └── L1c2b1c -3022.2
#     │       │   │   │   │       └── L1c2b2 -2920.2
#     │       │   │   │   └── L1c4 -2767.2
#     │       │   │   │       ├── L1c4a -3124.2
#     │       │   │   │       └── L1c4b -2818.2
#     │       │   │   └── L1c6 -2563.2
#     │       │   └── L1c5 -2741.7
#     │       └── L1c3 -2537.7
#     │           ├── L1c3a -2711.6
#     │           │   └── L1c3a1 -2737.1
#     │           │       ├── L1c3a1a -2788.1
#     │           │       └── L1c3a1b -2788.1
#     │           └── L1c3b'c -2537.7
#     │               ├── L1c3b -2639.7
#     │               │   ├── L1c3b1 -2843.7
#     │               │   │   ├── L1c3b1a -2920.2
#     │               │   │   └── L1c3b1b -2894.7
#     │               │   └── L1c3b2 -2894.7
#     │               └── L1c3c -2818.2
#     └── L2'3'4'5'6 -2180.7
#         ├── L5 -2333.7
#         │   ├── L5a -2971.2
#         │   │   ├── L5a1 -3047.7
#         │   │   │   ├── L5a1a -3098.7
#         │   │   │   ├── L5a1b -3098.7
#         │   │   │   └── L5a1c -3098.7
#         │   │   └── L5a2 -3022.2
#         │   └── L5b -2359.2
#         │       ├── L5b1 -2792.7
#         │       │   ├── L5b1a -2869.2
#         │       │   └── L5b1b -2818.2
#         │       └── L5b2 -3073.2
#         └── L2'3'4'6 -2206.2
#             ├── L2 -2384.7
#             │   ├── L2a'b'c'd -2410.2
#             │   │   ├── L2a -2435.7
#             │   │   │   ├── L2a1'2'3'4 -2588.7
#             │   │   │   │   ├── L2a1 -2665.2
#             │   │   │   │   │   ├── L2a1a -2767.2
#             │   │   │   │   │   │   ├── L2a1a1 -2843.7
#             │   │   │   │   │   │   ├── L2a1a2 -2792.7
#             │   │   │   │   │   │   │   ├── L2a1a2a -2818.2
#             │   │   │   │   │   │   │   │   └── L2a1a2a1 -2843.7
#             │   │   │   │   │   │   │   │       └── L2a1a2a1a -2869.2
#             │   │   │   │   │   │   │   ├── L2a1a2b -2818.2
#             │   │   │   │   │   │   │   └── L2a1a2c -2869.2
#             │   │   │   │   │   │   └── L2a1a3 -2792.7
#             │   │   │   │   │   │       ├── L2a1a3a -2818.2
#             │   │   │   │   │   │       ├── L2a1a3b -2818.2
#             │   │   │   │   │   │       └── L2a1a3c -2843.7
#             │   │   │   │   │   ├── - -2665.2
#             │   │   │   │   │   │   ├── L2a1b -2690.7
#             │   │   │   │   │   │   │   ├── L2a1b1 -2716.2
#             │   │   │   │   │   │   │   │   └── L2a1b1a -2767.2
#             │   │   │   │   │   │   │   ├── L2a1b2 -2716.2
#             │   │   │   │   │   │   │   └── - -2716.2
#             │   │   │   │   │   │   │       └── L2a1b3 -2767.2
#             │   │   │   │   │   │   ├── L2a1f -2690.7
#             │   │   │   │   │   │   │   ├── L2a1f1 -2716.2
#             │   │   │   │   │   │   │   │   └── L2a1f1a -2741.7
#             │   │   │   │   │   │   │   ├── L2a1f2 -2716.2
#             │   │   │   │   │   │   │   └── L2a1f3 -2716.2
#             │   │   │   │   │   │   └── L2a1g -2792.7
#             │   │   │   │   │   └── - -2690.7
#             │   │   │   │   │       ├── L2a1c -2741.7
#             │   │   │   │   │       │   ├── - -2767.2
#             │   │   │   │   │       │   │   ├── L2a1c1 -2818.2
#             │   │   │   │   │       │   │   │   └── L2a1c1a -2843.7
#             │   │   │   │   │       │   │   │       ├── L2a1c1a1 -2869.2
#             │   │   │   │   │       │   │   │       └── L2a1c1a2 -2869.2
#             │   │   │   │   │       │   │   └── L2a1c6 -2818.2
#             │   │   │   │   │       │   ├── L2a1c2 -2818.2
#             │   │   │   │   │       │   │   └── L2a1c2a -2843.7
#             │   │   │   │   │       │   ├── L2a1c3 -2767.2
#             │   │   │   │   │       │   │   ├── L2a1c3a -2792.7
#             │   │   │   │   │       │   │   │   └── L2a1c3a1 -2843.7
#             │   │   │   │   │       │   │   └── L2a1c3b -2792.7
#             │   │   │   │   │       │   │       ├── L2a1c3b1 -2818.2
#             │   │   │   │   │       │   │       └── L2a1c3b2 -2869.2
#             │   │   │   │   │       │   ├── L2a1c4 -2767.2
#             │   │   │   │   │       │   │   └── L2a1c4a -2792.7
#             │   │   │   │   │       │   │       └── L2a1c4a1 -2818.2
#             │   │   │   │   │       │   └── - -2741.7
#             │   │   │   │   │       │       └── L2a1c5 -2767.2
#             │   │   │   │   │       ├── - -2690.7
#             │   │   │   │   │       │   ├── L2a1d -2818.2
#             │   │   │   │   │       │   │   ├── L2a1d1 -2945.7
#             │   │   │   │   │       │   │   └── L2a1d2 -2843.7
#             │   │   │   │   │       │   └── L2a1h -2767.2
#             │   │   │   │   │       ├── L2a1e -2767.2
#             │   │   │   │   │       │   └── L2a1e1 -2818.2
#             │   │   │   │   │       └── - -2690.7
#             │   │   │   │   │           ├── - -2690.7
#             │   │   │   │   │           │   ├── L2a1i -2741.7
#             │   │   │   │   │           │   │   └── L2a1i1 -2792.7
#             │   │   │   │   │           │   └── L2a1q -2767.2
#             │   │   │   │   │           ├── L2a1j -2741.7
#             │   │   │   │   │           ├── L2a1k -2767.2
#             │   │   │   │   │           ├── L2a1l -2716.2
#             │   │   │   │   │           │   ├── L2a1l1 -2741.7
#             │   │   │   │   │           │   │   ├── L2a1l1a -2767.2
#             │   │   │   │   │           │   │   │   ├── L2a1l1a1 -2792.7
#             │   │   │   │   │           │   │   │   └── L2a1l1a2 -2792.7
#             │   │   │   │   │           │   │   └── L2a1l1b -2767.2
#             │   │   │   │   │           │   ├── L2a1l2 -2741.7
#             │   │   │   │   │           │   │   └── L2a1l2a -2767.2
#             │   │   │   │   │           │   │       └── L2a1l2a1 -2792.7
#             │   │   │   │   │           │   └── L2a1l3 -2741.7
#             │   │   │   │   │           ├── L2a1m -2716.2
#             │   │   │   │   │           │   └── L2a1m1 -2716.2
#             │   │   │   │   │           │       └── L2a1m1a -2741.7
#             │   │   │   │   │           ├── L2a1n -2716.2
#             │   │   │   │   │           ├── L2a1o -2716.2
#             │   │   │   │   │           └── L2a1p -2767.2
#             │   │   │   │   └── L2a2'3'4 -2639.7
#             │   │   │   │       ├── L2a2'3 -2665.2
#             │   │   │   │       │   ├── L2a2 -2690.7
#             │   │   │   │       │   │   ├── L2a2a -2767.2
#             │   │   │   │       │   │   │   └── L2a2a1 -2792.7
#             │   │   │   │       │   │   └── L2a2b -2741.7
#             │   │   │   │       │   │       ├── L2a2b1 -2767.2
#             │   │   │   │       │   │       │   └── L2a2b1a -2869.2
#             │   │   │   │       │   │       └── L2a2b2 -2818.2
#             │   │   │   │       │   └── L2a3 -2792.7
#             │   │   │   │       └── L2a4 -2767.2
#             │   │   │   │           ├── L2a4a -2920.2
#             │   │   │   │           └── L2a4b -2843.7
#             │   │   │   └── L2a5 -2639.7
#             │   │   └── L2b'c'd -2435.7
#             │   │       ├── L2b'c -2588.7
#             │   │       │   ├── L2b -2971.2
#             │   │       │   │   ├── L2b1 -3098.7
#             │   │       │   │   │   ├── L2b1a -3124.2
#             │   │       │   │   │   │   ├── L2b1a2 -3149.7
#             │   │       │   │   │   │   ├── L2b1a3 -3149.7
#             │   │       │   │   │   │   └── L2b1a4 -3149.7
#             │   │       │   │   │   └── L2b1b -3149.7
#             │   │       │   │   ├── L2b2 -3047.7
#             │   │       │   │   │   └── L2b2a -3149.7
#             │   │       │   │   └── L2b3 -2971.2
#             │   │       │   │       ├── L2b3a -3098.7
#             │   │       │   │       ├── L2b3b -2996.7
#             │   │       │   │       └── L2b3c -2996.7
#             │   │       │   └── L2c -2741.7
#             │   │       │       ├── L2c1 -2767.2
#             │   │       │       │   └── L2c1a -2792.7
#             │   │       │       ├── L2c2 -2741.7
#             │   │       │       │   ├── L2c2a -2767.2
#             │   │       │       │   │   └── L2c2a1 -2843.7
#             │   │       │       │   └── L2c2b -2767.2
#             │   │       │       │       ├── L2c2b1 -2818.2
#             │   │       │       │       │   ├── L2c2b1a -2869.2
#             │   │       │       │       │   └── L2c2b1b -2894.7
#             │   │       │       │       └── L2c2b2 -2792.7
#             │   │       │       ├── L2c3 -2767.2
#             │   │       │       │   └── L2c3a -2818.2
#             │   │       │       ├── L2c4 -2767.2
#             │   │       │       └── L2c5 -2767.2
#             │   │       └── L2d -2792.7
#             │   │           └── - -2792.7
#             │   │               └── L2d1 -2818.2
#             │   │                   └── L2d1a -2920.2
#             │   └── L2e -2920.2
#             │       └── L2e1 -2945.7
#             │           └── L2e1a -3022.2
#             └── L3'4'6 -2206.2
#                 ├── L6 -2690.7
#                 │   ├── L6a -2741.7
#                 │   └── L6b -2716.2
#                 └── L3'4 -2206.2
#                     ├── L4 -2257.2
#                     │   ├── L4a -2512.2
#                     │   │   ├── L4a1 -2690.7
#                     │   │   │   └── L4a1a -2767.2
#                     │   │   └── L4a2 -2512.2
#                     │   └── L4b -2257.2
#                     │       ├── L4b1 -2359.2
#                     │       │   └── L4b1a -2843.7
#                     │       └── L4b2 -2461.2
#                     │           ├── L4b2a -2486.7
#                     │           │   ├── L4b2a1 -2639.7
#                     │           │   └── L4b2a2 -2588.7
#                     │           │       ├── L4b2a2a -2665.2
#                     │           │       ├── L4b2a2b -2690.7
#                     │           │       └── L4b2a2c -2665.2
#                     │           └── L4b2b -2563.2
#                     │               └── L4b2b1 -2665.2
#                     └── L3 -2206.2
#                         ├── L3a -2282.7
#                         │   ├── L3a1 -2410.2
#                         │   │   ├── L3a1a -2435.7
#                         │   │   └── L3a1b -2563.2
#                         │   └── - -2257.2
#                         │       └── L3a2 -2308.2
#                         │           └── L3a2a -2359.2
#                         ├── L3b'f -2206.2
#                         │   ├── L3b -2461.2
#                         │   │   ├── L3b1 -2486.7
#                         │   │   │   ├── L3b1a -2512.2
#                         │   │   │   │   ├── L3b1a1 -2537.7
#                         │   │   │   │   │   └── L3b1a1a -2563.2
#                         │   │   │   │   ├── L3b1a2 -2537.7
#                         │   │   │   │   ├── L3b1a3 -2537.7
#                         │   │   │   │   ├── L3b1a4 -2563.2
#                         │   │   │   │   ├── L3b1a5 -2537.7
#                         │   │   │   │   │   └── L3b1a5a -2563.2
#                         │   │   │   │   ├── - -2512.2
#                         │   │   │   │   │   └── L3b1a6 -2588.7
#                         │   │   │   │   ├── - -2512.2
#                         │   │   │   │   │   ├── L3b1a7 -2614.2
#                         │   │   │   │   │   │   └── L3b1a7a -2639.7
#                         │   │   │   │   │   ├── L3b1a8 -2563.2
#                         │   │   │   │   │   └── L3b1a9 -2537.7
#                         │   │   │   │   │       └── L3b1a9a -2563.2
#                         │   │   │   │   ├── L3b1a10 -2563.2
#                         │   │   │   │   └── L3b1a11 -2537.7
#                         │   │   │   └── L3b1b -2537.7
#                         │   │   │       └── L3b1b1 -2563.2
#                         │   │   ├── L3b2 -2537.7
#                         │   │   │   ├── L3b2a -2563.2
#                         │   │   │   └── L3b2b -2614.2
#                         │   │   └── L3b3 -2563.2
#                         │   └── L3f -2308.2
#                         │       ├── L3f1 -2359.2
#                         │       │   ├── L3f1a -2435.7
#                         │       │   │   └── L3f1a1 -2486.7
#                         │       │   └── L3f1b -2435.7
#                         │       │       ├── - -2410.2
#                         │       │       │   ├── L3f1b1 -2435.7
#                         │       │       │   │   └── L3f1b1a -2486.7
#                         │       │       │   │       └── L3f1b1a1 -2512.2
#                         │       │       │   ├── L3f1b2 -2435.7
#                         │       │       │   │   └── L3f1b2a -2486.7
#                         │       │       │   ├── - -2435.7
#                         │       │       │   │   ├── L3f1b3 -2512.2
#                         │       │       │   │   └── L3f1b4 -2461.2
#                         │       │       │   │       ├── L3f1b4a -2486.7
#                         │       │       │   │       │   └── L3f1b4a1 -2512.2
#                         │       │       │   │       ├── L3f1b4b -2486.7
#                         │       │       │   │       └── L3f1b4c -2486.7
#                         │       │       │   └── L3f1b5 -2435.7
#                         │       │       └── L3f1b6 -2435.7
#                         │       ├── L3f2 -2308.2
#                         │       │   ├── L3f2a -2333.7
#                         │       │   │   └── L3f2a1 -2410.2
#                         │       │   │       └── L3f2a1a -2461.2
#                         │       │   └── L3f2b -2461.2
#                         │       └── L3f3 -2614.2
#                         │           ├── L3f3a -2639.7
#                         │           └── L3f3b -2639.7
#                         ├── L3c'd -2206.2
#                         │   ├── L3c -2486.7
#                         │   └── L3d -2359.2
#                         │       └── L3d1'2'3'4'5'6 -2384.7
#                         │           ├── L3d1 -2410.2
#                         │           │   ├── L3d1a -2486.7
#                         │           │   │   └── L3d1a1'2 -2512.2
#                         │           │   │       ├── L3d1a1 -2537.7
#                         │           │   │       │   ├── L3d1a1a -2639.7
#                         │           │   │       │   │   └── L3d1a1a1 -2665.2
#                         │           │   │       │   └── L3d1a1b -2690.7
#                         │           │   │       └── L3d1a2 -2537.7
#                         │           │   ├── L3d1b -2435.7
#                         │           │   │   ├── L3d1b1 -2461.2
#                         │           │   │   │   ├── L3d1b1a -2486.7
#                         │           │   │   │   └── L3d1b1b -2512.2
#                         │           │   │   ├── L3d1b2 -2512.2
#                         │           │   │   └── L3d1b3 -2486.7
#                         │           │   │       └── L3d1b3a -2512.2
#                         │           │   ├── L3d1c -2563.2
#                         │           │   │   └── L3d1c1 -2614.2
#                         │           │   └── L3d1d -2461.2
#                         │           ├── L3d2 -2461.2
#                         │           │   ├── L3d2a -2435.7
#                         │           │   └── L3d2b -2486.7
#                         │           ├── L3d3 -2461.2
#                         │           │   ├── L3d3a -2563.2
#                         │           │   │   └── L3d3a1 -2588.7
#                         │           │   │       ├── L3d3a1a -2614.2
#                         │           │   │       └── L3d3a1b -2614.2
#                         │           │   └── L3d3b -2435.7
#                         │           ├── L3d4 -2359.2
#                         │           │   └── L3d4a -2410.2
#                         │           ├── L3d5 -2435.7
#                         │           │   └── L3d5a -2512.2
#                         │           └── L3d6 -2512.2
#                         ├── L3e'i'k'x -2257.2
#                         │   ├── L3e -2257.2
#                         │   │   ├── L3e1 -2410.2
#                         │   │   │   ├── L3e1a -2435.7
#                         │   │   │   │   ├── L3e1a1 -2461.2
#                         │   │   │   │   │   └── L3e1a1a -2486.7
#                         │   │   │   │   ├── L3e1a2 -2588.7
#                         │   │   │   │   └── L3e1a3 -2435.7
#                         │   │   │   │       ├── L3e1a3a -2486.7
#                         │   │   │   │       └── L3e1a3b -2512.2
#                         │   │   │   ├── L3e1b -2435.7
#                         │   │   │   │   ├── L3e1b1 -2461.2
#                         │   │   │   │   └── L3e1b2 -2486.6
#                         │   │   │   ├── L3e1c -2435.7
#                         │   │   │   ├── L3e1d -2435.7
#                         │   │   │   │   └── L3e1d1 -2512.2
#                         │   │   │   │       └── L3e1d1a -2537.7
#                         │   │   │   ├── L3e1e -2435.7
#                         │   │   │   │   ├── L3e1e1 -2461.2
#                         │   │   │   │   └── L3e1e2 -2537.7
#                         │   │   │   ├── L3e1f -2410.2
#                         │   │   │   │   ├── L3e1f1 -2410.2
#                         │   │   │   │   │   └── L3e1f1a -2461.2
#                         │   │   │   │   └── L3e1f2 -2486.7
#                         │   │   │   └── L3e1g -2665.2
#                         │   │   ├── L3e2 -2308.2
#                         │   │   │   ├── L3e2a -2359.2
#                         │   │   │   │   ├── L3e2a1 -2384.7
#                         │   │   │   │   │   ├── L3e2a1a -2486.7
#                         │   │   │   │   │   └── L3e2a1b -2410.2
#                         │   │   │   │   │       ├── L3e2a1b1 -2435.7
#                         │   │   │   │   │       ├── L3e2a1b2 -2435.7
#                         │   │   │   │   │       └── L3e2a1b3 -2435.7
#                         │   │   │   │   ├── L3e2a2 -2384.7
#                         │   │   │   │   └── L3e2a3 -2410.2
#                         │   │   │   └── L3e2b -2333.7
#                         │   │   │       ├── L3e2b1 -2359.2
#                         │   │   │       │   └── L3e2b1a -2384.7
#                         │   │   │       │       ├── L3e2b1a1 -2410.2
#                         │   │   │       │       └── L3e2b1a2 -2435.7
#                         │   │   │       ├── L3e2b2 -2359.2
#                         │   │   │       ├── - -2333.7
#                         │   │   │       │   ├── L3e2b3 -2359.2
#                         │   │   │       │   ├── L3e2b4 -2359.2
#                         │   │   │       │   ├── L3e2b5 -2359.2
#                         │   │   │       │   └── L3e2b6 -2359.2
#                         │   │   │       ├── L3e2b7 -2359.2
#                         │   │   │       └── L3e2b8 -2359.2
#                         │   │   └── L3e3'4'5 -2257.2
#                         │   │       ├── L3e3'4 -2282.7
#                         │   │       │   ├── L3e3 -2461.2
#                         │   │       │   │   ├── L3e3a -2512.2
#                         │   │       │   │   └── L3e3b -2588.7
#                         │   │       │   │       ├── L3e3b1 -2614.2
#                         │   │       │   │       ├── L3e3b2 -2614.2
#                         │   │       │   │       └── L3e3b3 -2614.2
#                         │   │       │   └── L3e4 -2410.2
#                         │   │       │       └── L3e4a -2384.7
#                         │   │       │           └── L3e4a1 -2410.2
#                         │   │       └── L3e5 -2333.7
#                         │   │           ├── L3e5a -2359.2
#                         │   │           │   └── L3e5a1 -2384.7
#                         │   │           │       └── L3e5a1a -2410.2
#                         │   │           ├── L3e5b -2359.2
#                         │   │           ├── - -2333.7
#                         │   │           │   └── L3e5c -2359.2
#                         │   │           ├── L3e5d -2384.7
#                         │   │           ├── L3e5e -2384.7
#                         │   │           └── L3e5f -2410.2
#                         │   ├── L3i -2282.7
#                         │   │   ├── L3i1 -2384.7
#                         │   │   │   ├── L3i1a -2410.2
#                         │   │   │   └── L3i1b -2435.7
#                         │   │   └── L3i2 -2384.7
#                         │   ├── L3k -2486.7
#                         │   │   └── L3k1 -2665.2
#                         │   └── L3x -2410.2
#                         │       ├── L3x1 -2461.2
#                         │       │   ├── L3x1a -2486.7
#                         │       │   │   ├── L3x1a1 -2486.7
#                         │       │   │   └── L3x1a2 -2512.2
#                         │       │   └── - -2461.2
#                         │       │       └── L3x1b -2486.7
#                         │       └── L3x2 -2512.2
#                         │           ├── L3x2a -2537.7
#                         │           │   └── L3x2a1 -2613.1
#                         │           │       └── L3x2a1a -2689.6
#                         │           └── L3x2b -2639.7
#                         ├── L3h -2257.2
#                         │   ├── L3h1 -2384.7
#                         │   │   ├── L3h1a -2410.2
#                         │   │   │   ├── L3h1a1 -2614.2
#                         │   │   │   └── L3h1a2 -2435.7
#                         │   │   │       ├── L3h1a2a -2588.7
#                         │   │   │       │   └── L3h1a2a1 -2639.7
#                         │   │   │       └── L3h1a2b -2410.2
#                         │   │   └── L3h1b -2461.2
#                         │   │       ├── L3h1b1 -2486.7
#                         │   │       │   └── L3h1b1a -2537.7
#                         │   │       └── L3h1b2 -2690.7
#                         │   └── L3h2 -2690.7
#                         ├── M -2308.2
#                         │   ├── M1'20'51 -2333.7
#                         │   │   ├── M1 -2461.2
#                         │   │   │   ├── M1a -2512.2
#                         │   │   │   │   ├── M1a1 -2588.7
#                         │   │   │   │   │   ├── M1a1a -2614.2
#                         │   │   │   │   │   │   └── M1a1a1 -2690.7
#                         │   │   │   │   │   ├── M1a1b -2639.7
#                         │   │   │   │   │   │   ├── M1a1b1 -2614.2
#                         │   │   │   │   │   │   │   ├── M1a1b1a -2639.7
#                         │   │   │   │   │   │   │   ├── M1a1b1b -2639.7
#                         │   │   │   │   │   │   │   │   └── M1a1b1b1 -2665.2
#                         │   │   │   │   │   │   │   └── M1a1b1c -2665.2
#                         │   │   │   │   │   │   └── M1a1b2 -2665.2
#                         │   │   │   │   │   ├── - -2614.2
#                         │   │   │   │   │   │   ├── M1a1c -2741.7
#                         │   │   │   │   │   │   └── M1a1d -2665.2
#                         │   │   │   │   │   ├── M1a1e -2614.2
#                         │   │   │   │   │   │   ├── M1a1e1 -2639.7
#                         │   │   │   │   │   │   └── M1a1e2 -2614.2
#                         │   │   │   │   │   ├── M1a1f -2614.2
#                         │   │   │   │   │   ├── M1a1g -2690.7
#                         │   │   │   │   │   ├── M1a1h -2614.2
#                         │   │   │   │   │   └── M1a1i -2665.2
#                         │   │   │   │   ├── M1a2 -2537.7
#                         │   │   │   │   │   ├── M1a2a -2563.2
#                         │   │   │   │   │   └── M1a2b -2614.2
#                         │   │   │   │   ├── M1a3 -2537.7
#                         │   │   │   │   │   ├── M1a3a -2563.2
#                         │   │   │   │   │   └── M1a3b -2563.2
#                         │   │   │   │   │       ├── M1a3b1 -2614.2
#                         │   │   │   │   │       └── M1a3b2 -2588.7
#                         │   │   │   │   ├── M1a4 -2563.2
#                         │   │   │   │   │   └── M1a4a -2614.2
#                         │   │   │   │   ├── M1a5 -2639.7
#                         │   │   │   │   ├── M1a6 -2537.7
#                         │   │   │   │   ├── M1a7 -2537.7
#                         │   │   │   │   └── M1a8 -2537.7
#                         │   │   │   │       └── M1a8a -2588.7
#                         │   │   │   └── M1b -2486.7
#                         │   │   │       ├── M1b1 -2614.2
#                         │   │   │       │   ├── M1b1a -2665.2
#                         │   │   │       │   └── M1b1b -2665.2
#                         │   │   │       └── M1b2 -2537.7
#                         │   │   │           ├── M1b2a -2588.7
#                         │   │   │           ├── M1b2b -2614.2
#                         │   │   │           └── M1b2c -2563.2
#                         │   │   ├── M20 -2741.7
#                         │   │   └── M51 -2512.2
#                         │   │       ├── M51a -2537.7
#                         │   │       │   ├── M51a1 -2614.2
#                         │   │       │   │   ├── M51a1a -2716.2
#                         │   │       │   │   └── M51a1b -2741.7
#                         │   │       │   └── M51a2 -2690.7
#                         │   │       └── M51b -2537.7
#                         │   │           └── M51b1 -2588.7
#                         │   │               ├── M51b1a -2639.7
#                         │   │               └── M51b1b -2792.7
#                         │   ├── M2 -2435.7
#                         │   │   ├── M2a'b -2486.7
#                         │   │   │   ├── M2a -2537.7
#                         │   │   │   │   ├── M2a1 -2639.7
#                         │   │   │   │   │   ├── M2a1a -2639.7
#                         │   │   │   │   │   │   ├── M2a1a1 -2687.2999999999997
#                         │   │   │   │   │   │   │   ├── M2a1a1a -2712.7999999999997
#                         │   │   │   │   │   │   │   │   └── M2a1a1a1 -2763.7999999999997
#                         │   │   │   │   │   │   │   └── M2a1a1b -2712.7999999999997
#                         │   │   │   │   │   │   │       └── M2a1a1b1 -2738.2999999999997
#                         │   │   │   │   │   │   ├── M2a1a2 -2665.2
#                         │   │   │   │   │   │   │   └── M2a1a2a -2690.7
#                         │   │   │   │   │   │   │       └── M2a1a2a1 -2741.7
#                         │   │   │   │   │   │   │           └── M2a1a2a1a -2767.2
#                         │   │   │   │   │   │   └── - -2665.2
#                         │   │   │   │   │   │       └── M2a1a3 -2716.2
#                         │   │   │   │   │   │           └── - -2741.7
#                         │   │   │   │   │   │               ├── M2a1a3a -2767.2
#                         │   │   │   │   │   │               │   └── M2a1a3a1 -2792.7
#                         │   │   │   │   │   │               └── M2a1a3b -2767.2
#                         │   │   │   │   │   ├── M2a1b -2792.7
#                         │   │   │   │   │   └── M2a1c -2690.7
#                         │   │   │   │   ├── M2a2 -2665.2
#                         │   │   │   │   │   └── M2a2a -2716.2
#                         │   │   │   │   └── M2a3 -2614.2
#                         │   │   │   │       └── M2a3a -2639.7
#                         │   │   │   └── M2b -2690.7
#                         │   │   │       ├── M2b1 -2741.7
#                         │   │   │       │   ├── M2b1a -2894.7
#                         │   │   │       │   └── M2b1b -2971.2
#                         │   │   │       ├── M2b2 -2716.2
#                         │   │   │       ├── M2b3 -2716.2
#                         │   │   │       │   └── M2b3a -2741.7
#                         │   │   │       └── M2b4 -2792.7
#                         │   │   └── M2c -2537.7
#                         │   ├── M3 -2308.2
#                         │   │   ├── M3a -2333.7
#                         │   │   │   ├── M3a1 -2359.2
#                         │   │   │   │   └── - -2384.7
#                         │   │   │   │       ├── M3a1a -2410.2
#                         │   │   │   │       └── M3a1b -2410.2
#                         │   │   │   └── M3a2 -2384.7
#                         │   │   │       └── M3a2a -2461.2
#                         │   │   ├── M3b -2384.7
#                         │   │   ├── M3c -2333.7
#                         │   │   │   ├── - -2333.7
#                         │   │   │   │   └── M3c1 -2435.7
#                         │   │   │   │       ├── M3c1a -2461.2
#                         │   │   │   │       └── M3c1b -2537.7
#                         │   │   │   │           └── M3c1b1 -2588.7
#                         │   │   │   │               ├── M3c1b1a -2639.7
#                         │   │   │   │               └── M3c1b1b -2614.2
#                         │   │   │   └── M3c2 -2359.2
#                         │   │   └── M3d -2359.2
#                         │   │       └── M3d1 -2410.2
#                         │   │           └── M3d1a -2435.7
#                         │   │               └── M3d1a1 -2461.2
#                         │   ├── M467 -2333.7
#                         │   │   ├── - -2333.7
#                         │   │   │   ├── M4 -2435.7
#                         │   │   │   │   ├── M4a -2461.2
#                         │   │   │   │   └── M4b -2486.7
#                         │   │   │   ├── M65 -2359.2
#                         │   │   │   │   ├── M65a -2435.7
#                         │   │   │   │   │   ├── M65a1 -2563.2
#                         │   │   │   │   │   └── - -2435.7
#                         │   │   │   │   │       └── M65a2 -2486.7
#                         │   │   │   │   └── M65b -2435.7
#                         │   │   │   └── M67 -2665.2
#                         │   │   ├── M18'38 -2359.2
#                         │   │   │   ├── M18 -2435.7
#                         │   │   │   │   ├── M18a -2486.7
#                         │   │   │   │   ├── M18b -2512.2
#                         │   │   │   │   └── M18c -2486.7
#                         │   │   │   └── M38 -2435.7
#                         │   │   │       ├── M38a -2512.2
#                         │   │   │       ├── - -2435.7
#                         │   │   │       │   ├── M38b -2639.7
#                         │   │   │       │   └── M38c -2614.2
#                         │   │   │       └── - -2461.2
#                         │   │   │           ├── M38d -2639.7
#                         │   │   │           └── M38e -2614.2
#                         │   │   ├── M30 -2384.7
#                         │   │   │   ├── M30a -2410.2
#                         │   │   │   │   ├── M30a1 -2435.7
#                         │   │   │   │   └── M30a2 -2435.7
#                         │   │   │   ├── M30b -2410.2
#                         │   │   │   ├── M30c -2410.2
#                         │   │   │   │   └── M30c1 -2410.2
#                         │   │   │   │       └── M30c1a -2435.7
#                         │   │   │   │           └── M30c1a1 -2461.2
#                         │   │   │   ├── M30d -2410.2
#                         │   │   │   │   ├── M30d1 -2435.7
#                         │   │   │   │   └── M30d2 -2435.7
#                         │   │   │   ├── - -2410.2
#                         │   │   │   │   └── M30e -2461.2
#                         │   │   │   ├── M30f -2435.7
#                         │   │   │   └── M30g -2435.7
#                         │   │   ├── M37 -2359.2
#                         │   │   │   ├── - -2359.2
#                         │   │   │   │   └── - -2384.7
#                         │   │   │   │       ├── M37a -2384.7
#                         │   │   │   │       │   └── M37a1 -2410.2
#                         │   │   │   │       └── M37d -2410.2
#                         │   │   │   └── M37e -2435.7
#                         │   │   │       └── M37e2 -2461.2
#                         │   │   ├── M43 -2384.7
#                         │   │   │   ├── - -2384.7
#                         │   │   │   │   └── M43a -2410.2
#                         │   │   │   │       └── M43a1 -2512.2
#                         │   │   │   └── M43b -2435.7
#                         │   │   ├── M45 -2359.2
#                         │   │   │   └── M45a -2461.2
#                         │   │   ├── M54 -2435.7
#                         │   │   ├── M63 -2563.2
#                         │   │   ├── M64 -2537.7
#                         │   │   └── M66 -2410.2
#                         │   │       ├── M66a -2461.2
#                         │   │       └── M66b -2435.7
#                         │   ├── M5 -2333.7
#                         │   │   ├── M5a'd -2308.2
#                         │   │   │   ├── M5a -2333.7
#                         │   │   │   │   ├── M5a1 -2410.2
#                         │   │   │   │   │   ├── M5a1a -2461.2
#                         │   │   │   │   │   └── M5a1b -2461.2
#                         │   │   │   │   ├── M5a2 -2359.2
#                         │   │   │   │   │   └── M5a2a -2384.7
#                         │   │   │   │   │       ├── M5a2a1 -2410.2
#                         │   │   │   │   │       │   └── M5a2a1a -2435.7
#                         │   │   │   │   │       │       ├── M5a2a1a1 -2461.2
#                         │   │   │   │   │       │       └── M5a2a1a2 -2410.2
#                         │   │   │   │   │       ├── M5a2a2 -2435.7
#                         │   │   │   │   │       ├── M5a2a3 -2410.2
#                         │   │   │   │   │       └── M5a2a4 -2486.7
#                         │   │   │   │   ├── M5a3 -2384.7
#                         │   │   │   │   │   ├── M5a3a -2435.7
#                         │   │   │   │   │   └── M5a3b -2410.2
#                         │   │   │   │   ├── M5a4 -2384.7
#                         │   │   │   │   └── M5a5 -2359.2
#                         │   │   │   └── M5d -2359.2
#                         │   │   └── M5b'c -2359.2
#                         │   │       ├── M5b -2384.7
#                         │   │       │   ├── M5b1 -2486.7
#                         │   │       │   └── M5b2 -2435.7
#                         │   │       │       ├── M5b2a -2486.7
#                         │   │       │       └── M5b2b -2461.2
#                         │   │       │           └── M5b2b1 -2486.7
#                         │   │       │               └── M5b2b1a -2563.2
#                         │   │       └── M5c -2410.2
#                         │   │           ├── M5c1 -2512.2
#                         │   │           └── M5c2 -2512.2
#                         │   ├── M6 -2461.2
#                         │   │   ├── M6a -2537.7
#                         │   │   │   ├── M6a1 -2614.2
#                         │   │   │   │   ├── M6a1a -2665.2
#                         │   │   │   │   └── M6a1b -2767.2
#                         │   │   │   └── M6a2 -2639.7
#                         │   │   └── M6b -2512.2
#                         │   ├── M7 -2359.2
#                         │   │   ├── M7a -2512.2
#                         │   │   │   ├── - -2537.7
#                         │   │   │   │   └── M7a1 -2563.2
#                         │   │   │   │       ├── M7a1a -2614.2
#                         │   │   │   │       │   ├── M7a1a1 -2639.7
#                         │   │   │   │       │   │   └── M7a1a1a -2665.2
#                         │   │   │   │       │   ├── M7a1a2 -2690.7
#                         │   │   │   │       │   ├── M7a1a3 -2665.2
#                         │   │   │   │       │   ├── M7a1a4 -2665.2
#                         │   │   │   │       │   │   └── M7a1a4a -2741.7
#                         │   │   │   │       │   ├── M7a1a5 -2639.7
#                         │   │   │   │       │   │   └── M7a1a5a -2665.2
#                         │   │   │   │       │   ├── M7a1a6 -2639.7
#                         │   │   │   │       │   │   └── M7a1a6a -2639.7
#                         │   │   │   │       │   ├── M7a1a7 -2639.7
#                         │   │   │   │       │   ├── M7a1a8 -2665.2
#                         │   │   │   │       │   └── M7a1a9 -2639.7
#                         │   │   │   │       └── M7a1b -2639.7
#                         │   │   │   │           ├── M7a1b1 -2741.7
#                         │   │   │   │           └── M7a1b2 -2767.2
#                         │   │   │   └── M7a2 -2537.7
#                         │   │   │       └── M7a2a -2563.2
#                         │   │   │           ├── M7a2a1 -2639.7
#                         │   │   │           ├── M7a2a2 -2614.2
#                         │   │   │           └── M7a2a3 -2639.7
#                         │   │   │               └── M7a2a3a -2665.2
#                         │   │   └── M7b'c -2384.7
#                         │   │       ├── M7b -2410.2
#                         │   │       │   ├── M7b1 -2512.2
#                         │   │       │   │   ├── M7b1a -2639.7
#                         │   │       │   │   │   ├── M7b1a1 -2690.7
#                         │   │       │   │   │   │   ├── M7b1a1a -2690.7
#                         │   │       │   │   │   │   │   ├── M7b1a1a1 -2741.7
#                         │   │       │   │   │   │   │   │   ├── M7b1a1a1a -2767.2
#                         │   │       │   │   │   │   │   │   ├── M7b1a1a1b -2767.2
# ...
#                                                 │       │   │   │   │   │   └── K1a1b1g -2665.2
#                                                 │       │   │   │   │   └── K1a1b2 -2614.2
#                                                 │       │   │   │   │       ├── K1a1b2a -2665.2
#                                                 │       │   │   │   │       │   └── K1a1b2a1 -2716.2
#                                                 │       │   │   │   │       │       └── K1a1b2a1a -2741.7
#                                                 │       │   │   │   │       └── K1a1b2b -2614.2
#                                                 │       │   │   │   └── K1a1c -2614.2
#                                                 │       │   │   ├── K1a2 -2588.7
#                                                 │       │   │   │   ├── K1a2a -2614.2
#                                                 │       │   │   │   │   ├── K1a2a1 -2665.2
#                                                 │       │   │   │   │   └── K1a2a2 -2639.7
#                                                 │       │   │   │   ├── K1a2b -2614.2
#                                                 │       │   │   │   └── K1a2c -2639.7
#                                                 │       │   │   ├── K1a3 -2588.7
#                                                 │       │   │   │   └── K1a3a -2614.2
#                                                 │       │   │   │       ├── K1a3a1 -2639.7
#                                                 │       │   │   │       │   ├── K1a3a1a -2716.2
#                                                 │       │   │   │       │   └── K1a3a1b -2665.2
#                                                 │       │   │   │       ├── K1a3a2 -2639.7
#                                                 │       │   │   │       ├── K1a3a3 -2639.7
#                                                 │       │   │   │       └── K1a3a4 -2665.2
#                                                 │       │   │   ├── K1a4 -2588.7
#                                                 │       │   │   │   ├── K1a4a -2614.2
#                                                 │       │   │   │   │   └── K1a4a1 -2665.2
#                                                 │       │   │   │   │       ├── K1a4a1a -2716.2
#                                                 │       │   │   │   │       │   ├── - -2716.2
#                                                 │       │   │   │   │       │   │   ├── K1a4a1a1 -2741.7
#                                                 │       │   │   │   │       │   │   └── K1a4a1a3 -2741.7
#                                                 │       │   │   │   │       │   └── K1a4a1a2 -2741.7
#                                                 │       │   │   │   │       │       ├── K1a4a1a2a -2767.2
#                                                 │       │   │   │   │       │       └── K1a4a1a2b -2767.2
#                                                 │       │   │   │   │       ├── K1a4a1b -2690.7
#                                                 │       │   │   │   │       │   ├── K1a4a1b1 -2716.2
#                                                 │       │   │   │   │       │   └── K1a4a1b2 -2716.2
#                                                 │       │   │   │   │       ├── K1a4a1c -2690.7
#                                                 │       │   │   │   │       │   └── K1a4a1c1 -2716.2
#                                                 │       │   │   │   │       ├── K1a4a1d -2690.7
#                                                 │       │   │   │   │       ├── K1a4a1e -2665.2
#                                                 │       │   │   │   │       ├── K1a4a1f -2716.2
#                                                 │       │   │   │   │       │   └── K1a4a1f1 -2767.2
#                                                 │       │   │   │   │       ├── K1a4a1g -2716.2
#                                                 │       │   │   │   │       ├── K1a4a1h -2690.7
#                                                 │       │   │   │   │       └── K1a4a1i -2690.7
#                                                 │       │   │   │   ├── K1a4b -2639.7
#                                                 │       │   │   │   │   └── K1a4b1 -2716.2
#                                                 │       │   │   │   ├── K1a4c -2639.7
#                                                 │       │   │   │   │   └── K1a4c1 -2716.2
#                                                 │       │   │   │   ├── K1a4d -2665.2
#                                                 │       │   │   │   ├── K1a4e -2614.2
#                                                 │       │   │   │   ├── K1a4f -2614.2
#                                                 │       │   │   │   │   └── K1a4f1 -2639.7
#                                                 │       │   │   │   ├── K1a4g -2614.2
#                                                 │       │   │   │   ├── K1a4h -2639.7
#                                                 │       │   │   │   │   └── K1a4h1 -2665.2
#                                                 │       │   │   │   ├── K1a4i -2614.2
#                                                 │       │   │   │   └── - -2588.7
#                                                 │       │   │   │       └── K1a4j -2614.2
#                                                 │       │   │   │           └── K1a4j1 -2639.7
#                                                 │       │   │   ├── K1a5 -2588.7
#                                                 │       │   │   │   ├── K1a5a -2665.2
#                                                 │       │   │   │   └── K1a5b -2690.7
#                                                 │       │   │   ├── K1a6 -2639.7
#                                                 │       │   │   ├── K1a7 -2588.7
#                                                 │       │   │   ├── K1a8 -2588.7
#                                                 │       │   │   │   ├── K1a8a -2639.7
#                                                 │       │   │   │   │   └── K1a8a1 -2665.2
#                                                 │       │   │   │   └── K1a8b -2639.7
#                                                 │       │   │   ├── - -2563.2
#                                                 │       │   │   │   ├── K1a9 -2588.7
#                                                 │       │   │   │   ├── K1a10 -2588.7
#                                                 │       │   │   │   │   └── K1a10a -2614.2
#                                                 │       │   │   │   ├── K1a13 -2614.2
#                                                 │       │   │   │   │   └── K1a13a -2639.7
#                                                 │       │   │   │   ├── K1a14 -2639.7
#                                                 │       │   │   │   ├── K1a15 -2588.7
#                                                 │       │   │   │   ├── K1a16 -2588.7
#                                                 │       │   │   │   └── K1a26 -2588.7
#                                                 │       │   │   ├── - -2588.7
#                                                 │       │   │   │   ├── K1a11 -2658.2
#                                                 │       │   │   │   │   ├── K1a11a -2683.7
#                                                 │       │   │   │   │   │   └── K1a11a1 -2709.2
#                                                 │       │   │   │   │   └── K1a11b -2683.7
#                                                 │       │   │   │   ├── K1a24 -2614.2
#                                                 │       │   │   │   │   └── K1a24a -2690.7
#                                                 │       │   │   │   ├── K1a30 -2614.2
#                                                 │       │   │   │   │   └── K1a30a -2639.7
#                                                 │       │   │   │   └── K1a31 -2614.2
#                                                 │       │   │   ├── K1a12 -2588.7
#                                                 │       │   │   │   └── K1a12a -2614.2
#                                                 │       │   │   │       └── K1a12a1 -2639.7
#                                                 │       │   │   │           └── K1a12a1a -2665.2
#                                                 │       │   │   ├── K1a17 -2614.2
#                                                 │       │   │   │   └── K1a17a -2665.2
#                                                 │       │   │   ├── K1a18 -2614.2
#                                                 │       │   │   ├── K1a19 -2588.7
#                                                 │       │   │   │   └── K1a19a -2764.6
#                                                 │       │   │   ├── K1a23 -2588.7
#                                                 │       │   │   ├── K1a25 -2614.2
#                                                 │       │   │   ├── K1a27 -2614.2
#                                                 │       │   │   ├── K1a28 -2665.2
#                                                 │       │   │   └── K1a29 -2588.7
#                                                 │       │   │       └── K1a29a -2639.7
#                                                 │       │   ├── K1b -2563.2
#                                                 │       │   │   ├── K1b1 -2639.7
#                                                 │       │   │   │   ├── - -2639.7
#                                                 │       │   │   │   │   ├── K1b1a -2741.7
#                                                 │       │   │   │   │   │   ├── K1b1a1 -2767.2
#                                                 │       │   │   │   │   │   │   ├── - -2792.7
#                                                 │       │   │   │   │   │   │   │   ├── K1b1a1a -2818.2
#                                                 │       │   │   │   │   │   │   │   └── K1b1a1b -2818.2
#                                                 │       │   │   │   │   │   │   ├── K1b1a1c -2818.2
#                                                 │       │   │   │   │   │   │   │   └── K1b1a1c1 -2843.7
#                                                 │       │   │   │   │   │   │   └── K1b1a1d -2792.7
#                                                 │       │   │   │   │   │   │       └── K1b1a1d1 -2818.2
#                                                 │       │   │   │   │   │   └── K1b1a2 -2843.7
#                                                 │       │   │   │   │   └── K1b1b -2690.7
#                                                 │       │   │   │   │       └── K1b1b1 -2741.7
#                                                 │       │   │   │   └── K1b1c -2690.7
#                                                 │       │   │   └── K1b2 -2588.7
#                                                 │       │   │       ├── K1b2a -2614.2
#                                                 │       │   │       │   ├── K1b2a1 -2639.7
#                                                 │       │   │       │   │   └── K1b2a1a -2665.2
#                                                 │       │   │       │   │       └── K1b2a1a1 -2690.7
#                                                 │       │   │       │   ├── K1b2a2 -2614.2
#                                                 │       │   │       │   │   └── K1b2a2a -2639.7
#                                                 │       │   │       │   └── K1b2a3 -2639.7
#                                                 │       │   │       └── K1b2b -2665.2
#                                                 │       │   │           └── K1b2b1 -2690.7
#                                                 │       │   ├── K1c -2537.7
#                                                 │       │   │   ├── K1c1 -2588.7
#                                                 │       │   │   │   ├── K1c1a -2614.2
#                                                 │       │   │   │   ├── K1c1b -2614.2
#                                                 │       │   │   │   ├── K1c1c -2614.2
#                                                 │       │   │   │   ├── K1c1d -2665.2
#                                                 │       │   │   │   ├── K1c1e -2614.2
#                                                 │       │   │   │   ├── K1c1f -2614.2
#                                                 │       │   │   │   ├── K1c1g -2614.2
#                                                 │       │   │   │   ├── K1c1h -2614.2
#                                                 │       │   │   │   └── K1c1i -2614.2
#                                                 │       │   │   └── K1c2 -2639.7
#                                                 │       │   │       └── K1c2a -2639.7
#                                                 │       │   └── - -2563.2
#                                                 │       │       ├── K1d -2639.7
#                                                 │       │       │   └── K1d1 -2665.2
#                                                 │       │       ├── K1e -2665.2
#                                                 │       │       │   └── K1e1 -2741.7
#                                                 │       │       └── K1f -2614.2
#                                                 │       ├── K2 -2537.7
#                                                 │       │   ├── K2a -2537.7
#                                                 │       │   │   ├── K2a1 -2614.2
#                                                 │       │   │   │   └── K2a1a -2639.7
#                                                 │       │   │   ├── K2a2 -2563.2
#                                                 │       │   │   │   └── K2a2a -2588.7
#                                                 │       │   │   │       └── K2a2a1 -2639.7
#                                                 │       │   │   ├── K2a3 -2563.2
#                                                 │       │   │   │   └── K2a3a -2588.7
#                                                 │       │   │   │       └── K2a3a1 -2614.2
#                                                 │       │   │   ├── K2a4 -2563.2
#                                                 │       │   │   ├── K2a5 -2563.2
#                                                 │       │   │   │   ├── K2a5a -2588.7
#                                                 │       │   │   │   │   └── K2a5a1 -2639.7
#                                                 │       │   │   │   └── K2a5b -2588.7
#                                                 │       │   │   ├── K2a6 -2563.2
#                                                 │       │   │   ├── K2a7 -2563.2
#                                                 │       │   │   ├── K2a8 -2563.2
#                                                 │       │   │   ├── K2a9 -2588.7
#                                                 │       │   │   ├── K2a10 -2563.2
#                                                 │       │   │   └── K2a11 -2563.2
#                                                 │       │   ├── K2b -2614.2
#                                                 │       │   │   ├── K2b1 -2639.7
#                                                 │       │   │   │   ├── K2b1a -2665.2
#                                                 │       │   │   │   │   ├── K2b1a1 -2639.7
#                                                 │       │   │   │   │   │   └── K2b1a1a -2665.2
#                                                 │       │   │   │   │   ├── K2b1a2 -2690.7
#                                                 │       │   │   │   │   ├── K2b1a3 -2690.7
#                                                 │       │   │   │   │   └── K2b1a4 -2741.7
#                                                 │       │   │   │   └── K2b1b -2716.2
#                                                 │       │   │   └── K2b2 -2639.7
#                                                 │       │   └── K2c -2563.2
#                                                 │       └── K3 -2767.2
#                                                 └── U8c -2410.2

# %%
a.parent == None
# Out:
# True

# %%
from anytree import find_by_attr, PreOrderIter

# %%
minx = -1000000
for i in PreOrderIter(a):
    if i.lh >= minx:
        minx = i.lh
for i in PreOrderIter(a):
    if i.lh == minx:
        print(i.name)
# Out:
# L1b2

# %%
s = find_by_attr(a,'L1b2')

# %%
s.snps
# Out:
# [['A', 'G', 189],
#  ['C', 'T', 12891],
#  ['A', 'G', 13893],
#  ['G', 'A', 14323],
#  ['C', 'T', 16239]]

# %%
ref.fetch('chrM')[18]
# Out:
# 'C'

# %%
PreOrderIter(a)
# Out:
# mt-MRCA (RSRS) -2206.2

# %%
key = lambda x: x.lh

# %%
S = list()
for i in PreOrderIter(a):
    S.append(i)

# %%
S.sort(key = key,reverse=True)

# %%
S
# Out:
# [L1b2 -1390.1999999999998,
#  L1b2a -1441.1999999999998,
#  L1b -1517.6999999999998,
#  L1b2'3 -1517.6999999999998,
#  L1b3 -1619.6999999999998,
#  L1b1 -1645.1999999999998,
#  - -1645.1999999999998,
#  L1b1a -1670.6999999999998,
#  L1b1a1'4 -1670.6999999999998,
#  L1b1a3 -1670.6999999999998,
#  L1b1a9 -1670.6999999999998,
#  L1b1a17 -1670.6999999999998,
#  L1b1a4 -1696.1999999999998,
#  L1b1a2 -1696.1999999999998,
#  L1b1a3a -1696.1999999999998,
#  L1b1a15 -1696.1999999999998,
#  L1b1a18 -1696.1999999999998,
#  L1b1a5 -1696.1999999999998,
#  L1b1a7 -1696.1999999999998,
#  L1b1a8 -1696.1999999999998,
#  L1b1a10 -1696.1999999999998,
#  L1b1a13 -1696.1999999999998,
#  L1b1a14 -1696.1999999999998,
#  L1b1a4a -1721.6999999999998,
#  L1b1a2a -1721.6999999999998,
#  L1b1a3a1 -1721.6999999999998,
#  L1b1a3b -1721.6999999999998,
#  L1b1a15a -1721.6999999999998,
#  L1b1a6 -1721.6999999999998,
#  L1b1a10a -1721.6999999999998,
#  L1b1a10b -1721.6999999999998,
#  L1b1a12 -1721.6999999999998,
#  L1b1a16 -1721.6999999999998,
#  L1b1a1 -1747.1999999999998,
#  L1b1a7a -1747.1999999999998,
#  L1b1a12a -1747.1999999999998,
#  L1b1a12b -1747.1999999999998,
#  L1 -2027.6999999999998,
#  L1'2'3'4'5'6 -2180.7,
#  L2'3'4'5'6 -2180.7,
#  H24 -2180.7,
#  mt-MRCA (RSRS) -2206.2,
#  L2'3'4'6 -2206.2,
#  L3'4'6 -2206.2,
#  L3'4 -2206.2,
#  L3 -2206.2,
#  L3b'f -2206.2,
#  L3c'd -2206.2,
#  N -2206.2,
#  R -2206.2,
#  R0 -2206.2,
#  HV -2206.2,
#  - -2206.2,
#  HV5 -2206.2,
#  - -2206.2,
#  HV7 -2206.2,
#  HV14 -2206.2,
#  H -2206.2,
#  H1ak -2206.2,
#  H1ba -2206.2,
#  - -2206.2,
#  H2 -2206.2,
#  H2a -2206.2,
#  H2a2 -2206.2,
#  H2a2a -2206.2,
#  H2a2a1 -2206.2,
#  H2a2a1g -2206.2,
#  - -2206.2,
#  H2a2b1 -2206.2,
#  - -2206.2,
#  - -2206.2,
#  - -2206.2,
#  - -2206.2,
#  - -2206.2,
#  H24a -2206.2,
#  H24b -2206.2,
#  H94 -2206.2,
#  H96 -2206.2,
#  H99 -2206.2,
#  - -2206.2,
#  B4'5 -2206.2,
#  H57 -2230.7,
#  N1'5 -2231.7,
#  N2 -2231.7,
#  N9 -2231.7,
#  N11 -2231.7,
#  S -2231.7,
#  - -2231.7,
#  HV2 -2231.7,
#  HV20 -2231.7,
#  HV4 -2231.7,
#  HV5a -2231.7,
#  HV8 -2231.7,
#  HV9 -2231.7,
#  - -2231.7,
#  HV10 -2231.7,
#  HV11 -2231.7,
#  HV14a -2231.7,
#  HV16 -2231.7,
#  HV23 -2231.7,
#  HV24 -2231.7,
#  HV12 -2231.7,
#  HV12a -2231.7,
#  HV13 -2231.7,
#  HV18 -2231.7,
#  HV21 -2231.7,
#  H1 -2231.7,
#  - -2231.7,
#  - -2231.7,
#  H1ak1 -2231.7,
#  H1ak2 -2231.7,
#  - -2231.7,
#  H1ba1 -2231.7,
#  H1bf -2231.7,
#  H1bh -2231.7,
#  H1ch -2231.7,
#  - -2231.7,
#  H2a2a1a -2231.7,
#  H2a2a1b -2231.7,
#  H2a2a1d -2231.7,
#  H2a2a1e -2231.7,
#  H2a2a1f -2231.7,
#  H2a2a1h -2231.7,
#  H2a2a2 -2231.7,
#  H2a2b -2231.7,
#  H2a2b1a -2231.7,
#  H2a3 -2231.7,
#  H2a4 -2231.7,
#  H2a5 -2231.7,
#  H2b -2231.7,
#  H3 -2231.7,
#  - -2231.7,
#  H3a -2231.7,
#  - -2231.7,
#  - -2231.7,
#  H3am -2231.7,
#  H3ap -2231.7,
#  H3aq -2231.7,
#  - -2231.7,
#  H5'36 -2231.7,
#  - -2231.7,
#  H7 -2231.7,
#  H91 -2231.7,
#  H108 -2231.7,
#  H9 -2231.7,
#  H32 -2231.7,
#  H46 -2231.7,
#  H52 -2231.7,
#  H69 -2231.7,
#  H10 -2231.7,
#  H10a1 -2231.7,
#  H10c -2231.7,
#  - -2231.7,
#  H13 -2231.7,
#  H13a2 -2231.7,
#  H16 -2231.7,
#  - -2231.7,
#  H17 -2231.7,
#  H17c -2231.7,
#  H27 -2231.7,
#  H27e -2231.7,
#  - -2231.7,
#  H20 -2231.7,
#  H23 -2231.7,
#  H24a2 -2231.7,
#  H25 -2231.7,
#  H26 -2231.7,
#  H28 -2231.7,
#  H30 -2231.7,
#  H33 -2231.7,
#  - -2231.7,
#  H35 -2231.7,
#  H39 -2231.7,
#  H39a -2231.7,
#  H40 -2231.7,
#  H40a -2231.7,
#  H41 -2231.7,
#  H42 -2231.7,
#  H43 -2231.7,
#  H44 -2231.7,
#  H45 -2231.7,
#  H48 -2231.7,
#  H49 -2231.7,
#  H50 -2231.7,
#  H51 -2231.7,
#  H53 -2231.7,
#  H54 -2231.7,
#  H55 -2231.7,
#  H56 -2231.7,
#  H58 -2231.7,
#  H59 -2231.7,
#  H60 -2231.7,
#  H62 -2231.7,
#  H65 -2231.7,
#  H66 -2231.7,
#  H67 -2231.7,
#  H70 -2231.7,
#  H71 -2231.7,
#  H73 -2231.7,
#  H76 -2231.7,
#  H77 -2231.7,
#  H78 -2231.7,
#  H79 -2231.7,
#  H80 -2231.7,
#  H81 -2231.7,
#  H82 -2231.7,
#  H83 -2231.7,
#  H84 -2231.7,
#  H86 -2231.7,
#  H87 -2231.7,
#  H88 -2231.7,
#  H92 -2231.7,
#  H93 -2231.7,
#  H95 -2231.7,
#  H100 -2231.7,
#  H104 -2231.7,
#  H105 -2231.7,
#  R1 -2231.7,
#  R2'JT -2231.7,
#  R11'B6 -2231.7,
#  B4 -2231.7,
#  R30 -2231.7,
#  R31 -2231.7,
#  P -2231.7,
#  HV0 -2253.6,
#  - -2253.6,
#  H7g -2253.7999999999997,
#  L4 -2257.2,
#  L4b -2257.2,
#  - -2257.2,
#  L3e'i'k'x -2257.2,
#  L3e -2257.2,
#  L3e3'4'5 -2257.2,
#  L3h -2257.2,
#  Y -2257.2,
#  HV1 -2257.2,
#  HV4a -2257.2,
#  HV5b -2257.2,
#  HV6 -2257.2,
#  HV9a -2257.2,
#  HV9b -2257.2,
#  HV9c -2257.2,
#  HV15 -2257.2,
#  HV17 -2257.2,
#  HV22 -2257.2,
#  HV13b -2257.2,
#  H1a -2257.2,
#  H1b -2257.2,
#  H1g -2257.2,
#  H1k -2257.2,
#  H1y -2257.2,
#  H1aa -2257.2,
#  H1aa1 -2257.2,
#  H1ab -2257.2,
#  H1ac -2257.2,
#  H1ad -2257.2,
#  H1c -2257.2,
#  - -2257.2,
#  H1c15 -2257.2,
#  H1e -2257.2,
#  - -2257.2,
#  H1e4a -2257.2,
#  H1h -2257.2,
#  H1h1 -2257.2,
#  H1i -2257.2,
#  H1an -2257.2,
#  H1bb -2257.2,
#  H1j -2257.2,
#  H1j1 -2257.2,
#  H1m -2257.2,
#  H1n -2257.2,
#  - -2257.2,
#  H1n4 -2257.2,
#  - -2257.2,
#  - -2257.2,
#  H1p -2257.2,
#  H1q -2257.2,
#  H1r -2257.2,
#  H1r1 -2257.2,
#  H1s -2257.2,
#  H1t -2257.2,
#  H1u -2257.2,
#  H1v -2257.2,
#  H1v1b -2257.2,
#  H1w -2257.2,
#  H1ae -2257.2,
#  H1af -2257.2,
#  H1ag -2257.2,
#  H1ai -2257.2,
#  H1aj -2257.2,
#  H1am -2257.2,
#  H1cg -2257.2,
#  H1ap -2257.2,
#  H1aq -2257.2,
#  H1as -2257.2,
#  H1at -2257.2,
#  H1au -2257.2,
#  H1av -2257.2,
#  H1aw -2257.2,
#  H1ay -2257.2,
#  H1az -2257.2,
#  H1bc -2257.2,
#  H1bd -2257.2,
#  H1bf1 -2257.2,
#  H1bg -2257.2,
#  H1bi -2257.2,
#  H1bj -2257.2,
#  H1bk -2257.2,
#  H1bm -2257.2,
#  H1bn -2257.2,
#  H1bp -2257.2,
#  H1bq -2257.2,
#  H1br -2257.2,
#  H1bs -2257.2,
#  H1bt -2257.2,
#  H1bv -2257.2,
#  H1bw -2257.2,
#  H1cf -2257.2,
#  H2a1 -2257.2,
#  - -2257.2,
#  H2a2a1c -2257.2,
#  H2a2b1a1 -2257.2,
#  H2a2b2 -2257.2,
#  H2a2b3 -2257.2,
#  H2a2b4 -2257.2,
#  H2a2b5 -2257.2,
#  H2a3a -2257.2,
#  H2a3b -2257.2,
#  H2a5a -2257.2,
#  H2a5b -2257.2,
#  H2a5b1 -2257.2,
#  H2c -2257.2,
#  H3a1 -2257.2,
#  H3g -2257.2,
#  H3i -2257.2,
#  H3j -2257.2,
#  H3k -2257.2,
#  H3k1a -2257.2,
#  H3b -2257.2,
#  - -2257.2,
#  H3b6 -2257.2,
#  H3c -2257.2,
#  H3d -2257.2,
#  H3h -2257.2,
#  H3m -2257.2,
#  H3p -2257.2,
#  H3q -2257.2,
#  H3r -2257.2,
#  H3t -2257.2,
#  H3u -2257.2,
#  H3v -2257.2,
#  H3x -2257.2,
#  H3y -2257.2,
#  H3z -2257.2,
#  H3aa -2257.2,
#  H3ac -2257.2,
#  H3ad -2257.2,
#  H3ae -2257.2,
#  H3af -2257.2,
#  H3ag -2257.2,
#  H3ah -2257.2,
#  H3ai -2257.2,
#  H3aj -2257.2,
#  H3an -2257.2,
#  H3ao -2257.2,
#  H3ar -2257.2,
#  H3as -2257.2,
#  H3at -2257.2,
#  H3au -2257.2,
#  H5 -2257.2,
#  H5a8 -2257.2,
#  - -2257.2,
#  H5v -2257.2,
#  H6 -2257.2,
#  H7a -2257.2,
#  H7b -2257.2,
#  H7c -2257.2,
#  H7d -2257.2,
#  H7f -2257.2,
#  H7h -2257.2,
#  H8 -2257.2,
#  - -2257.2,
#  - -2257.2,
#  H31 -2257.2,
#  H11 -2257.2,
#  H11a -2257.2,
#  - -2257.2,
#  H12 -2257.2,
#  H46b -2257.2,
#  H107 -2257.2,
#  H10a -2257.2,
#  H10a1a -2257.2,
#  H10b -2257.2,
#  H10d -2257.2,
#  H10e -2257.2,
#  H10f -2257.2,
#  H10g -2257.2,
#  H13a -2257.2,
#  H13a2a -2257.2,
#  H13a2b -2257.2,
#  H13b -2257.2,
#  H13c -2257.2,
#  H14 -2257.2,
#  H16a -2257.2,
#  H16c -2257.2,
#  H16b -2257.2,
#  H17a -2257.2,
#  H17b -2257.2,
#  - -2257.2,
#  H27c -2257.2,
#  H27d -2257.2,
#  H18 -2257.2,
#  H18b -2257.2,
#  H20a -2257.2,
#  H20a1 -2257.2,
#  H20c -2257.2,
#  H22 -2257.2,
#  H24a1 -2257.2,
#  H26a -2257.2,
#  H26c -2257.2,
#  H29 -2257.2,
#  H30b -2257.2,
#  H30b1 -2257.2,
#  H33a -2257.2,
#  H34 -2257.2,
#  H64 -2257.2,
#  H35a -2257.2,
#  H39a1 -2257.2,
#  H39b -2257.2,
#  H39c -2257.2,
#  H44b -2257.2,
#  H47 -2257.2,
#  H49a -2257.2,
#  H49b -2257.2,
#  - -2257.2,
#  H55b -2257.2,
#  H56a -2257.2,
#  H56b -2257.2,
#  H56c -2257.2,
#  H56d -2257.2,
#  H58a -2257.2,
#  H59a -2257.2,
#  H60a -2257.2,
#  H61 -2257.2,
#  H63 -2257.2,
#  H66a -2257.2,
#  H75 -2257.2,
#  H76a -2257.2,
#  H79a -2257.2,
#  H101 -2257.2,
#  H102 -2257.2,
#  H105a -2257.2,
#  H106 -2257.2,
#  JT -2257.2,
#  R6 -2257.2,
#  - -2257.2,
#  R7 -2257.2,
#  - -2257.2,
#  B5 -2257.2,
#  R12'21 -2257.2,
#  R30b -2257.2,
#  - -2257.2,
#  H15 -2272.4,
#  HV0a -2279.1,
#  HV0a1 -2279.1,
#  HV0b -2279.1,
#  HV0c -2279.1,
#  HV0d -2279.1,
#  HV0f -2279.1,
#  H31a -2279.1,
#  H74 -2279.1,
#  R0a'b -2281.7,
#  L3a -2282.7,
#  L3e3'4 -2282.7,
#  L3i -2282.7,
#  N1 -2282.7,
#  Y1 -2282.7,
#  N10 -2282.7,
#  O -2282.7,
#  S1 -2282.7,
#  HV1a'b'c -2282.7,
#  HV4a1 -2282.7,
#  HV4a2 -2282.7,
#  HV4b -2282.7,
#  HV4c -2282.7,
#  HV11a -2282.7,
#  HV17a -2282.7,
#  HV12b -2282.7,
#  HV19 -2282.7,
#  H1a2 -2282.7,
#  H1a3 -2282.7,
#  H1a4 -2282.7,
#  H1a7 -2282.7,
#  H1a8 -2282.7,
#  H1b1 -2282.7,
#  H1b1f -2282.7,
#  H1b3 -2282.7,
#  H1b4 -2282.7,
#  H1b5 -2282.7,
#  H1f -2282.7,
#  H1g1 -2282.7,
#  H1g2 -2282.7,
#  H1z -2282.7,
#  H1ab1 -2282.7,
#  H1c2 -2282.7,
#  H1c4 -2282.7,
#  H1c5 -2282.7,
#  H1c5a -2282.7,
#  H1c6 -2282.7,
#  H1c7 -2282.7,
#  H1c9 -2282.7,
#  H1c11 -2282.7,
#  H1c12 -2282.7,
#  H1c13 -2282.7,
#  H1c16 -2282.7,
#  H1c17 -2282.7,
#  H1c19 -2282.7,
#  H1c20 -2282.7,
#  H1c21 -2282.7,
#  H1c22 -2282.7,
#  H1e1 -2282.7,
#  H1e2 -2282.7,
#  H1e2c -2282.7,
#  H1e4 -2282.7,
#  H1e5 -2282.7,
#  H1e6 -2282.7,
#  H1e7 -2282.7,
#  H1e8 -2282.7,
#  H1i1 -2282.7,
#  H1i2 -2282.7,
#  H1an1 -2282.7,
#  H1j1a -2282.7,
#  H1j1b -2282.7,
#  H1j3 -2282.7,
#  H1j4 -2282.7,
#  H1j6 -2282.7,
#  H1j7 -2282.7,
#  H1j9 -2282.7,
#  H1n1 -2282.7,
#  H1n3 -2282.7,
#  H1n5 -2282.7,
#  H1ck -2282.7,
#  H1q1 -2282.7,
#  H1q2 -2282.7,
#  H1s1 -2282.7,
#  H1t1 -2282.7,
#  H1t2 -2282.7,
#  H1u1 -2282.7,
#  H1v1 -2282.7,
#  H1ae1 -2282.7,
#  H1ae2 -2282.7,
#  H1af1 -2282.7,
#  H1af1b -2282.7,
#  H1af2 -2282.7,
#  H1ag1 -2282.7,
#  H1ah -2282.7,
#  H1ai1 -2282.7,
#  H1am1 -2282.7,
#  H1ao -2282.7,
#  H1ao1 -2282.7,
#  H1ap1 -2282.7,
#  H1ar -2282.7,
#  H1as2 -2282.7,
#  H1at1 -2282.7,
#  H1au1 -2282.7,
#  H1av1 -2282.7,
#  H1aw1 -2282.7,
#  H1be -2282.7,
#  H1bu -2282.7,
#  H1bx -2282.7,
#  H1ca -2282.7,
#  H2a1c -2282.7,
#  H2a1e -2282.7,
#  H2a1f -2282.7,
#  H2a1g -2282.7,
#  H2a1k -2282.7,
#  H2a1m -2282.7,
#  H2a1n -2282.7,
#  H2a2b5a -2282.7,
#  H2a3a1 -2282.7,
#  H2a5a1 -2282.7,
#  H3a1a -2282.7,
#  H3g2 -2282.7,
#  H3g3 -2282.7,
#  H3g4 -2282.7,
#  H3i1 -2282.7,
#  H3k1 -2282.7,
#  H3b2 -2282.7,
#  H3b3 -2282.7,
#  H3b4 -2282.7,
#  H3b5 -2282.7,
#  H3b6a -2282.7,
#  H3b7 -2282.7,
#  H3c1 -2282.7,
#  H3c2 -2282.7,
#  H3e -2282.7,
#  H3h1 -2282.7,
#  H3h2 -2282.7,
#  H3h3 -2282.7,
#  H3h5 -2282.7,
#  H3h6 -2282.7,
#  H3h7 -2282.7,
#  H3q1 -2282.7,
#  H3r1 -2282.7,
#  H3s -2282.7,
#  - -2282.7,
#  H3x1 -2282.7,
#  H3ab -2282.7,
#  H3ao1 -2282.7,
#  H3at1 -2282.7,
#  H3av -2282.7,
#  H4 -2282.7,
#  H5a -2282.7,
#  H5a1n -2282.7,
#  - -2282.7,
#  H5b -2282.7,
#  H5c -2282.7,
#  H5d -2282.7,
#  H5e -2282.7,
#  H5f -2282.7,
#  H5g -2282.7,
#  H5m -2282.7,
#  H5n -2282.7,
#  H5p -2282.7,
#  - -2282.7,
#  H5u -2282.7,
#  H7a1 -2282.7,
#  H7b1 -2282.7,
#  H7b2 -2282.7,
#  H7b3 -2282.7,
#  H7b4 -2282.7,
#  H7b5 -2282.7,
#  H7b6 -2282.7,
#  H7c1 -2282.7,
#  H7c2 -2282.7,
#  H7c4 -2282.7,
#  H7d2 -2282.7,
#  H7d3 -2282.7,
#  H7e -2282.7,
#  H7h1 -2282.7,
#  H8a -2282.7,
#  H8b -2282.7,
#  H8c -2282.7,
#  H31b -2282.7,
#  H11a1 -2282.7,
#  H11a2 -2282.7,
#  H11a3 -2282.7,
#  H11a4 -2282.7,
#  H11a5 -2282.7,
#  H11a7 -2282.7,
#  H11a8 -2282.7,
#  H11b -2282.7,
#  H12a -2282.7,
#  H46a -2282.7,
#  H103 -2282.7,
#  H10a1a1 -2282.7,
#  H10b1 -2282.7,
#  H10c1 -2282.7,
#  H10e1 -2282.7,
#  H10e2 -2282.7,
#  H10e3 -2282.7,
#  H13a1 -2282.7,
#  - -2282.7,
#  H13a2b3 -2282.7,
#  H13a2b5 -2282.7,
#  H13a2c -2282.7,
#  H13a2c1 -2282.7,
#  H13c1 -2282.7,
#  H14b -2282.7,
#  H16a1 -2282.7,
#  H16d -2282.7,
#  H16e -2282.7,
#  H17a2 -2282.7,
#  H27a -2282.7,
#  H27b -2282.7,
#  H27f -2282.7,
#  H19 -2282.7,
#  H20a2 -2282.7,
#  H26a1 -2282.7,
#  H28a -2282.7,
#  H29a -2282.7,
#  H29b -2282.7,
#  H30a -2282.7,
#  H33b -2282.7,
#  H33c -2282.7,
#  H85 -2282.7,
#  H40b -2282.7,
#  H42a -2282.7,
#  H44a -2282.7,
#  H45a -2282.7,
#  H45b -2282.7,
#  H49a1 -2282.7,
#  H51a -2282.7,
#  H55a -2282.7,
#  H56a1 -2282.7,
#  H63a -2282.7,
#  H65a -2282.7,
#  H66a1 -2282.7,
#  H67a -2282.7,
#  H72 -2282.7,
#  H89 -2282.7,
#  R9 -2282.7,
#  R11 -2282.7,
#  B4g -2282.7,
#  B4i -2282.7,
#  B4m -2282.7,
#  B4b'd'e'j -2282.7,
#  B4c -2282.7,
#  B4c1a'b -2282.7,
#  P2'10 -2282.7,
#  P4 -2282.7,
#  P6 -2282.7,
#  P9 -2282.7,
#  U -2282.7,
#  U5 -2282.7,
#  H15a -2297.9,
#  H15b -2297.9,
#  H1ax -2304.2999999999997,
#  V -2304.6,
#  V2 -2304.6,
#  - -2304.6,
#  - -2304.6,
#  HV0e -2304.6,
#  HV0g -2304.6,
#  H1cc -2304.6,
#  R0a -2307.2,
#  - -2307.2,
#  H1b1g -2307.2,
#  L3a2 -2308.2,
#  L3f -2308.2,
#  L3f2 -2308.2,
#  L3e2 -2308.2,
#  M -2308.2,
#  M3 -2308.2,
#  M5a'd -2308.2,
#  M32'56 -2308.2,
#  Y1a -2308.2,
#  - -2308.2,
#  N21 -2308.2,
#  - -2308.2,
#  S2 -2308.2,
#  X -2308.2,
#  HV1a -2308.2,
#  HV1b -2308.2,
#  - -2308.2,
#  HV1c -2308.2,
#  - -2308.2,
#  HV4a2a -2308.2,
#  HV4a2b -2308.2,
#  HV9a1 -2308.2,
#  HV12b1 -2308.2,
#  H1a1 -2308.2,
#  H1a3a -2308.2,
#  H1a3a2 -2308.2,
#  H1a3b -2308.2,
#  H1a3c -2308.2,
#  H1a3d -2308.2,
#  H1a5 -2308.2,
#  H1a6 -2308.2,
#  H1a8a -2308.2,
#  H1a9 -2308.2,
#  - -2308.2,
#  H1b1e -2308.2,
#  H1b1i -2308.2,
#  H1b2 -2308.2,
#  - -2308.2,
#  H1k1 -2308.2,
#  H1z1 -2308.2,
#  H1c1 -2308.2,
#  H1c2a -2308.2,
#  H1c3 -2308.2,
#  H1c4a -2308.2,
#  H1c4b -2308.2,
#  H1c8 -2308.2,
#  H1c9a -2308.2,
#  H1c10 -2308.2,
#  H1c18 -2308.2,
#  H1e1a -2308.2,
#  - -2308.2,
#  H1e1b -2308.2,
#  H1e1c -2308.2,
#  H1e2a -2308.2,
#  H1e2b -2308.2,
#  H1e2d -2308.2,
#  H1e5a -2308.2,
#  H1e5b -2308.2,
#  H1e8a -2308.2,
#  H1i2a -2308.2,
#  H1an1a -2308.2,
#  H1an2 -2308.2,
#  H1j1a1 -2308.2,
#  H1j1a2 -2308.2,
#  H1j1c -2308.2,
#  H1j5 -2308.2,
#  H1j8 -2308.2,
#  H1m1 -2308.2,
#  H1n1a -2308.2,
#  H1n2 -2308.2,
#  H1o -2308.2,
#  H1q1a -2308.2,
#  H1t1a -2308.2,
#  H1u2 -2308.2,
#  H1v1a -2308.2,
#  H1ae2a -2308.2,
#  H1ae3 -2308.2,
#  H1af1a -2308.2,
#  H1ag1b -2308.2,
#  H1aj1 -2308.2,
#  H1aq1 -2308.2,
#  H1as1 -2308.2,
#  H1at1a -2308.2,
#  H1au1a -2308.2,
#  H1au1b -2308.2,
#  H1av1a -2308.2,
#  H1bt1 -2308.2,
#  H1bv1 -2308.2,
#  H1bz -2308.2,
#  H1ci -2308.2,
#  H2a1a -2308.2,
#  H2a1b -2308.2,
#  H2a1d -2308.2,
#  H2a1e1 -2308.2,
#  H2a1f1 -2308.2,
#  H2a1f2 -2308.2,
#  H2a1i -2308.2,
#  H2a1j -2308.2,
#  H2a5a1a -2308.2,
#  H2a5a1b -2308.2,
#  H2a5b2 -2308.2,
#  H3g1 -2308.2,
#  H3b1 -2308.2,
#  H3b4a -2308.2,
#  H3c2a -2308.2,
#  H3c2b -2308.2,
#  H3c2c -2308.2,
#  H3c3 -2308.2,
#  H3h2a -2308.2,
#  H3h3a -2308.2,
#  H3h3b -2308.2,
#  H3n -2308.2,
#  H3w -2308.2,
#  H3z1 -2308.2,
#  H3ag1 -2308.2,
#  H3ak -2308.2,
#  H4b -2308.2,
#  H4c -2308.2,
#  H4d -2308.2,
#  H5a1 -2308.2,
#  H5a1b -2308.2,
#  - -2308.2,
#  H5a2 -2308.2,
#  H5a5 -2308.2,
#  H5a9 -2308.2,
#  H5b1 -2308.2,
#  H5b3 -2308.2,
#  H5b5 -2308.2,
#  H5c1 -2308.2,
#  H5h -2308.2,
#  H5k -2308.2,
#  H5q -2308.2,
#  H5s -2308.2,
#  H6a -2308.2,
#  H6b -2308.2,
#  H6b1 -2308.2,
#  H6c -2308.2,
#  H7a1b -2308.2,
#  H7a1c -2308.2,
#  H7a1d -2308.2,
#  H7a2 -2308.2,
#  H7b2a -2308.2,
#  H7c3 -2308.2,
#  H7c5 -2308.2,
#  H7c6 -2308.2,
#  H7d1 -2308.2,
#  H7d2a -2308.2,
#  H7d3a -2308.2,
#  H8a1 -2308.2,
#  H8b1 -2308.2,
#  H11a2a -2308.2,
#  H11b1 -2308.2,
#  H9a -2308.2,
#  H10e1a -2308.2,
#  H10e3a -2308.2,
#  H10h -2308.2,
#  H13a1a -2308.2,
#  H13a1d -2308.2,
#  H13a2a1 -2308.2,
#  H13a2b1 -2308.2,
#  H13a2b2 -2308.2,
#  H13b1 -2308.2,
#  H13b2 -2308.2,
#  H13c2 -2308.2,
#  H14a -2308.2,
#  - -2308.2,
#  H14b1 -2308.2,
#  H14b4 -2308.2,
#  H17a1 -2308.2,
#  H20a1a -2308.2,
#  H21 -2308.2,
#  H26a1a -2308.2,
#  H26b -2308.2,
#  H28a2 -2308.2,
#  H42a1 -2308.2,
#  H47a -2308.2,
#  H49a2 -2308.2,
#  H61a -2308.2,
#  H73a -2308.2,
#  H90 -2308.2,
#  H95a -2308.2,
#  R9b -2308.2,
#  R11a -2308.2,
#  R11b -2308.2,
#  B6 -2308.2,
#  B4a -2308.2,
#  B4a1c -2308.2,
#  - -2308.2,
#  B4g1 -2308.2,
#  B4h -2308.2,
#  B4d -2308.2,
#  B4c1 -2308.2,
#  B4c1a -2308.2,
#  P9a -2308.2,
#  U2'3'4'7'8'9 -2308.2,
#  H15a1 -2323.4,
#  H15b1 -2323.4,
#  H1ax1 -2329.7999999999997,
#  V1 -2330.1,
#  V2a -2330.1,
#  V2b -2330.1,
#  V2c -2330.1,
#  V3 -2330.1,
#  V4 -2330.1,
#  V6 -2330.1,
#  V10 -2330.1,
#  V12 -2330.1,
#  V14 -2330.1,
#  V15 -2330.1,
#  V16 -2330.1,
#  V18 -2330.1,
#  - -2330.1,
#  V22 -2330.1,
#  V23 -2330.1,
#  V24 -2330.1,
#  V25 -2330.1,
#  V26 -2330.1,
#  V27 -2330.1,
#  V28 -2330.1,
#  R0a1 -2332.7,
#  - -2332.7,
#  R0a2'3 -2332.7,
#  L5 -2333.7,
#  L3f2a -2333.7,
#  L3e2b -2333.7,
#  - -2333.7,
#  L3e5 -2333.7,
#  - -2333.7,
#  M1'20'51 -2333.7,
#  M3a -2333.7,
#  M3c -2333.7,
#  - -2333.7,
#  M467 -2333.7,
#  - -2333.7,
#  M5 -2333.7,
#  M5a -2333.7,
#  M12'G -2333.7,
#  M13'46'61 -2333.7,
#  M19'53 -2333.7,
#  M21 -2333.7,
#  M22 -2333.7,
#  M23'75 -2333.7,
#  M24'41 -2333.7,
#  M29'Q -2333.7,
#  M33 -2333.7,
#  M34'57 -2333.7,
#  M35 -2333.7,
#  M39'70 -2333.7,
#  M42'74 -2333.7,
#  M55'77 -2333.7,
#  M73'79 -2333.7,
#  M80'D -2333.7,
#  N1a -2333.7,
#  Y1a1 -2333.7,
#  Y1a2 -2333.7,
#  Y1b -2333.7,
#  X1'2'3 -2333.7,
#  X1'3 -2333.7,
#  HV1a2 -2333.7,
#  HV1b3 -2333.7,
#  HV2a -2333.7,
#  HV4a1a -2333.7,
#  HV9a1a -2333.7,
#  H1a1a -2333.7,
#  H1a1b -2333.7,
#  H1a1c -2333.7,
#  H1a3a1 -2333.7,
#  H1a3a3 -2333.7,
#  H1a3a4 -2333.7,
#  H1a3b1 -2333.7,
#  H1a3c1 -2333.7,
#  H1b1a -2333.7,
#  ...]
